# %% [markdown]
# # Hand On the EPOS ICS-C API

# %% [markdown]
# ## Search
#
# *import requests* is a Python statement that imports the *requests* library, which is a popular Python library for making HTTP requests. The *requests* library provides an interface for sending HTTP requests and handling their responses, making it a popular good choice for RESTfull API access.

# %%
import requests

# %% [markdown]
# *api_url* is assigned to 'https://www.ics-c.epos-eu.org/api/v1/'. This represents the base URL for the EPOS ICS-C API.

# %%
api_url = 'https://www.ics-c.epos-eu.org/api/v1/'

# %% [markdown]
# the *requests* library to send an HTTP GET request to the EPOS ICS-C API search endpoint, and then extract the JSON data from the response.
# The parameter in the query *facets* is set to false, this parameter is set to true when the client want the API to return the information in a categorized structure, for example the EPOS Data Portal show the information as in different category on multiple levels.

# %%
search_endpoint = api_url + 'resources/search?facets=false'

response_search = requests.get(search_endpoint)
data = response_search.json()

# %% [markdown]
# This is a JSON object with two key:
#
# 1. "*filters*" which has an array of four objects as its value: "*keyword*", "*organisations*", "*sciencedomains*" and "*servicetype*". Each object represents a filter category and has two key-value pairs:
#     - "*name*": a string that represents the name of the filter category.
#     - "*children*": an array of objects that represent the subcategories for the filter category. Each subcategory object has two key-value pairs:
#         - "*id*": a string that represents a unique identifier for the subcategory.
#         - "*name*": a string that represents the name of the subcategory.
# 2. "results*" that holds an array of object representing all the resources available in the system.

# %%
data
# Out:
# {'filters': [{'children': [{'id': 'M2QgLyA0ZCBtb2RlbA==',
#      'name': '3d / 4d model'},
#     {'id': 'M2QvNGQgbW9kZWw=', 'name': '3d/4d model'},
#     {'id': 'YWNjZWxlcmF0aW9u', 'name': 'acceleration'},
#     {'id': 'YWNvdXN0aWMgbWVhc3VyZW1lbnRz', 'name': 'acoustic measurements'},
#     {'id': 'YWN0aXZlIGZhdWx0', 'name': 'active fault'},
#     {'id': 'YWN0aXZlIGZhdWx0cw==', 'name': 'active faults'},
#     {'id': 'YWlyIHF1YWxpdHkgZGF0YQ==', 'name': 'air quality data'},
#     {'id': 'YWlyIHRlbXBlcmF0dXJl', 'name': 'air temperature'},
#     {'id': 'YWxvcy1wYWxzYXI=', 'name': 'alos-palsar'},
#     {'id': 'YW5hbHl0aWNhbA==', 'name': 'analytical'},
#     {'id': 'YW5pc290cm9weQ==', 'name': 'anisotropy'},
#     {'id': 'YW50aHJvcG9nZW5pYyBoYXphcmRz', 'name': 'anthropogenic hazards'},
#     {'id': 'YW50aHJvcG9nZW5pYyBzZWlzbWljaXR5',
#      'name': 'anthropogenic seismicity'},
#     {'id': 'YXBwbGljYXRpb25z', 'name': 'applications'},
#     {'id': 'YXJlYQ==', 'name': 'area'},
#     {'id': 'YXJw', 'name': 'arp'},
#     {'id': 'YXNjZW5kaW5n', 'name': 'ascending'},
#     {'id': 'YXRtb3NwaGVyaWMgbW9uaXRvcmluZw==',
#      'name': 'atmospheric monitoring'},
#     {'id': 'YXRtb3NwaGVyaWMgcHJlc3N1cmU=', 'name': 'atmospheric pressure'},
#     {'id': 'YXVyb3JhbCBlbGVjdHJvamV0', 'name': 'auroral electrojet'},
#     {'id': 'YXZhaWxhYmlsaXR5', 'name': 'availability'},
#     {'id': 'YXZlcmFnZSByZXR1cm4gcGVyaW9k', 'name': 'average return period'},
#     {'id': 'YXZpYXRpb24gY29sb3IgY29kZQ==', 'name': 'aviation color code'},
#     {'id': 'YmFzaW4=', 'name': 'basin'},
#     {'id': 'YmFzaW4gZXZvbHV0aW9u', 'name': 'basin evolution'},
#     {'id': 'Ymdy', 'name': 'bgr'},
#     {'id': 'YmlibGlvZ3JhcGh5', 'name': 'bibliography'},
#     {'id': 'Ym9yZWhvbGU=', 'name': 'borehole'},
#     {'id': 'YnJpZ2h0bmVzcyB0ZW1wZXJhdHVyZSBkaWZmZXJlbmNl',
#      'name': 'brightness temperature difference'},
#     {'id': 'YnJpdHRsZSBkZWZvcm1hdGlvbg==', 'name': 'brittle deformation'},
#     {'id': 'YnVpbGRpbmdz', 'name': 'buildings'},
#     {'id': 'YnVsayByb2Nr', 'name': 'bulk rock'},
#     {'id': 'YnVsayByb2NrIGFuYWx5c2lz', 'name': 'bulk rock analysis'},
#     {'id': 'Y2FyYm9uIGRpb3hpZGU=', 'name': 'carbon dioxide'},
#     {'id': 'Y2F0YWxvZw==', 'name': 'catalog'},
#     {'id': 'Y2F0YWxvZ3Vl', 'name': 'catalogue'},
#     {'id': 'Y2hlbWljYWwgZGF0YSBzZXQ=', 'name': 'chemical data set'},
#     {'id': 'Y2l2aWwgYXZpYXRpb24=', 'name': 'civil aviation'},
#     {'id': 'Y2xlYW5lZCBnbnNzIHBvc2l0aW9uIHRpbWUgc2VyaWVz',
#      'name': 'cleaned gnss position time series'},
#     {'id': 'Y28yIGNvbmNlbnRyYXRpb24=', 'name': 'co2 concentration'},
#     {'id': 'Y28yIHN0YXRpb25z', 'name': 'co2 stations'},
#     {'id': 'Y29oZXJlbmNl', 'name': 'coherence'},
#     {'id': 'Y29tcGFjdGlvbiAvY29uc29saWRhdGlvbg==',
#      'name': 'compaction /consolidation'},
#     {'id': 'Y29tcGFzcw==', 'name': 'compass'},
#     {'id': 'Y29tcGFzcyBkaXJlY3Rpb24=', 'name': 'compass direction'},
#     {'id': 'Y29tcHJlc3Npb24=', 'name': 'compression'},
#     {'id': 'Y29tcHV0YXRpb25hbCB2b2xjYW5vbG9neQ==',
#      'name': 'computational volcanology'},
#     {'id': 'Y29tcHV0ZWQ=', 'name': 'computed'},
#     {'id': 'Y29udGludW91cyB3YXZlZm9ybQ==', 'name': 'continuous waveform'},
#     {'id': 'Y29udmVudGlvbmFsIGh5ZHJvY2FyYm9uIGV4dHJhY3Rpb24=',
#      'name': 'conventional hydrocarbon extraction'},
#     {'id': 'Y29vcmRpbmF0ZXM=', 'name': 'coordinates'},
#     {'id': 'Y29yZQ==', 'name': 'core'},
#     {'id': 'Y29yaW50aCByaWZ0IGxhYm9yYXRvcnk=',
#      'name': 'corinth rift laboratory'},
#     {'id': 'Y29zbW9za3ltZWQ=', 'name': 'cosmoskymed'},
#     {'id': 'Y3Js', 'name': 'crl'},
#     {'id': 'Y3J1c3Q=', 'name': 'crust'},
#     {'id': 'Y3J1c3QgYW5kIG1hbnRsZSBiZWhhdmlvcg==',
#      'name': 'crust and mantle behavior'},
#     {'id': 'Y3J1c3RhbA==', 'name': 'crustal'},
#     {'id': 'Y3J1c3RhbCBhbmQgdXBwZXIgbWFudGxlIHJoZW9sb2d5',
#      'name': 'crustal and upper mantle rheology'},
#     {'id': 'Y3J1c3RhbCBmYXVsdA==', 'name': 'crustal fault'},
#     {'id': 'Y3J1c3RhbCBmYXVsdHM=', 'name': 'crustal faults'},
#     {'id': 'Y3J1c3RhbCBtYWduZXRpc20=', 'name': 'crustal magnetism'},
#     {'id': 'Y3J5c3RhbCBhbmQgbWluZXJhbCBvcmllbnRhdGlvbg==',
#      'name': 'crystal and mineral orientation'},
#     {'id': 'ZGFtYWdlIHNjYWxl', 'name': 'damage scale'},
#     {'id': 'ZGF0YQ==', 'name': 'data'},
#     {'id': 'ZGF0YSBxdWFsaXR5', 'name': 'data quality'},
#     {'id': 'ZGF0YXF1YWxpdHk=', 'name': 'dataquality'},
#     {'id': 'ZGF0YXNlbGVjdA==', 'name': 'dataselect'},
#     {'id': 'ZGVjZXB0aW9uIGlzbGFuZA==', 'name': 'deception island'},
#     {'id': 'ZGVjbGluYXRpb24=', 'name': 'declination'},
#     {'id': 'ZGVmb3JtYXRpb24=', 'name': 'deformation'},
#     {'id': 'ZGVmb3JtYXRpb24gbWFwcw==', 'name': 'deformation maps'},
#     {'id': 'ZGVzY2VuZGluZw==', 'name': 'descending'},
#     {'id': 'ZGlnaXRhbCBpbWFnZSBjb3JyZWxhdGlvbiAoZGljKQ==',
#      'name': 'digital image correlation (dic)'},
#     {'id': 'ZGluc2Fy', 'name': 'dinsar'},
#     {'id': 'ZGlw', 'name': 'dip'},
#     {'id': 'ZGlyZWN0aW9uYWwgZGF0YQ==', 'name': 'directional data'},
#     {'id': 'ZGlzcGxhY2VtZW50', 'name': 'displacement'},
#     {'id': 'ZGlzdHVyYmVkIGRheQ==', 'name': 'disturbed day'},
#     {'id': 'ZG9jdW1lbnQgcmVwb3NpdG9yeQ==', 'name': 'document repository'},
#     {'id': 'ZG9wcGxlciBlZmZlY3Q=', 'name': 'doppler effect'},
#     {'id': 'ZHVjdGlsZSBkZWZvcm1hdGlvbg==', 'name': 'ductile deformation'},
#     {'id': 'ZWFydGggZWxlY3RyaWNhbCBjb25kdWN0aXZpdHk=',
#      'name': 'earth electrical conductivity'},
#     {'id': 'ZWFydGggc3RydWN0dXJl', 'name': 'earth structure'},
#     {'id': 'ZWFydGhxdWFrZQ==', 'name': 'earthquake'},
#     {'id': 'ZWFydGhxdWFrZSBpbnRlbnNpdHk=', 'name': 'earthquake intensity'},
#     {'id': 'ZWFydGhxdWFrZXM=', 'name': 'earthquakes'},
#     {'id': 'ZWFydGhyZXNvdXJjZW1s', 'name': 'earthresourceml'},
#     {'id': 'ZWZlaHI=', 'name': 'efehr'},
#     {'id': 'ZWZzbTIw', 'name': 'efsm20'},
#     {'id': 'ZWlkYQ==', 'name': 'eida'},
#     {'id': 'ZWlkYS13cw==', 'name': 'eida-ws'},
#     {'id': 'ZWwgaGllcnJv', 'name': 'el hierro'},
#     {'id': 'ZWxhc3RpYyBtb2R1bGk=', 'name': 'elastic moduli'},
#     {'id': 'ZWxlY3RyaWNhbCBjb25kdWN0aXZpdHk=',
#      'name': 'electrical conductivity'},
#     {'id': 'ZWxlY3Ryb21hZ25ldGljIGRhdGE=', 'name': 'electromagnetic data'},
#     {'id': 'ZWxlY3Ryb24gbWljcm9zY29weSAoc2VtLCBmaWItc2VtLCBzdGVtLCB0ZW0p',
#      'name': 'electron microscopy (sem, fib-sem, stem, tem)'},
#     {'id': 'ZW52aXJvbm1lbnRhbCBtYWduZXRpc20=',
#      'name': 'environmental magnetism'},
#     {'id': 'ZXBpY2VudHJhbCBkaXN0YW5jZQ==', 'name': 'epicentral distance'},
#     {'id': 'ZXBpY2VudHJhbCBpbnRlbnNpdHk=', 'name': 'epicentral intensity'},
#     {'id': 'ZXBpc29kZQ==', 'name': 'episode'},
#     {'id': 'ZXBpc29kZXMgcGxhdGZvcm0=', 'name': 'episodes platform'},
#     {'id': 'ZXJ1cHRpb24=', 'name': 'eruption'},
#     {'id': 'ZXJ1cHRpb24gc291cmNlIHBhcmFtZXRlcnM=',
#      'name': 'eruption source parameters'},
#     {'id': 'ZXNobTEz', 'name': 'eshm13'},
#     {'id': 'ZXNobTIw', 'name': 'eshm20'},
#     {'id': 'ZXN0aW1hdGVk', 'name': 'estimated'},
#     {'id': 'ZXRuYQ==', 'name': 'etna'},
#     {'id': 'ZXZlbnQ=', 'name': 'event'},
#     {'id': 'ZXZlbnQgaWRlbnRpZmllcg==', 'name': 'event identifier'},
#     {'id': 'ZXhwZXJpbWVudA==', 'name': 'experiment'},
#     {'id': 'ZXhwbG9zaXZlIGVydXB0aW9u', 'name': 'explosive eruption'},
#     {'id': 'ZXhwb3N1cmU=', 'name': 'exposure'},
#     {'id': 'ZXh0ZW5zaW9u', 'name': 'extension'},
#     {'id': 'ZmF1bHQ=', 'name': 'fault'},
#     {'id': 'ZmF1bHQgYW5kIGZvbGQgYmVoYXZpb3I=',
#      'name': 'fault and fold behavior'},
#     {'id': 'ZmF1bHQgYmVoYXZpb3I=', 'name': 'fault behavior'},
#     {'id': 'ZmF1bHQgcnVwdHVyZSBtb2RlbA==', 'name': 'fault rupture model'},
#     {'id': 'ZmF1bHRz', 'name': 'faults'},
#     {'id': 'ZmRzbi13cw==', 'name': 'fdsn-ws'},
#     {'id': 'ZmRzbi13c1wi', 'name': 'fdsn-ws\\"'},
#     {'id': 'ZmRzbndzLWV2ZW50', 'name': 'fdsnws-event'},
#     {'id': 'ZmVkZXJhdG9y', 'name': 'federator'},
#     {'id': 'ZmVsdCBpbnRlbnNpdHk=', 'name': 'felt intensity'},
#     {'id': 'ZmlsZQ==', 'name': 'file'},
#     {'id': 'ZmxvdyBkZXB0aA==', 'name': 'flow depth'},
#     {'id': 'ZmxvdyByYXRl', 'name': 'flow rate'},
#     {'id': 'Zmx1aWQgYW5kIHJhZGlvYWN0aXZlIHdhc3RlIHN0b3JhZ2U=',
#      'name': 'fluid and radioactive waste storage'},
#     {'id': 'Zmx1aWQgZmxvdywgdHJhbnNwb3J0IGFuZCBwZXJtZWFiaWxpdHk=',
#      'name': 'fluid flow, transport and permeability'},
#     {'id': 'Zmx1aWQgaW5jbHVzaW9ucyAoc29saWQsIGxpcXVpZCwgZ2FzKQ==',
#      'name': 'fluid inclusions (solid, liquid, gas)'},
#     {'id': 'Zmx1aWQtcm9jayBpbnRlcmFjdGlvbg==',
#      'name': 'fluid-rock interaction'},
#     {'id': 'Zmx1aWRz', 'name': 'fluids'},
#     {'id': 'Zm9jYWwgbWVjaGFuaXNt', 'name': 'focal mechanism'},
#     {'id': 'Zm9yZWNhc3Q=', 'name': 'forecast'},
#     {'id': 'ZnJhY3R1cmUgc3RyZW5ndGggL3NoZWFyIHN0cmVuZ3Ro',
#      'name': 'fracture strength /shear strength'},
#     {'id': 'ZnJhZ2lsaXR5IGN1cnZl', 'name': 'fragility curve'},
#     {'id': 'ZnJpY3Rpb24=', 'name': 'friction'},
#     {'id': 'ZnJpZGdl', 'name': 'fridge'},
#     {'id': 'ZnJpbmdlcw==', 'name': 'fringes'},
#     {'id': 'Z2Fycm90eGEgdm9sY2FuaWMgZmllbGQ=',
#      'name': 'garrotxa volcanic field'},
#     {'id': 'Z2VvLWVmZmVjdGl2aXR5', 'name': 'geo-effectivity'},
#     {'id': 'Z2VvLWhhemFyZCBmcmVxdWVuY3k=', 'name': 'geo-hazard frequency'},
#     {'id': 'Z2VvY2hlbWljYWw=', 'name': 'geochemical'},
#     {'id': 'Z2VvY2hlbWljYWwtZGF0YQ==', 'name': 'geochemical-data'},
#     {'id': 'Z2VvY2hlbWlzdHJ5', 'name': 'geochemistry'},
#     {'id': 'Z2VvY2hyb25vbG9neQ==', 'name': 'geochronology'},
#     {'id': 'Z2VvZGVzeQ==', 'name': 'geodesy'},
#     {'id': 'Z2VvZGV0aWM=', 'name': 'geodetic'},
#     {'id': 'Z2VvaGF6YXJk', 'name': 'geohazard'},
#     {'id': 'Z2VvaGF6YXJkcw==', 'name': 'geohazards'},
#     {'id': 'Z2VvbG9jYXRpb24=', 'name': 'geolocation'},
#     {'id': 'Z2VvbG9naWNhbCBwcm9jZXNz', 'name': 'geological process'},
#     {'id': 'Z2VvbG9naWN1bml0', 'name': 'geologicunit'},
#     {'id': 'Z2VvbG9neQ==', 'name': 'geology'},
#     {'id': 'Z2VvbWFnbmV0aWMgYWN0aXZpdHk=', 'name': 'geomagnetic activity'},
#     {'id': 'Z2VvbWFnbmV0aWMgaW5kZXg=', 'name': 'geomagnetic index'},
#     {'id': 'Z2VvbWFnbmV0aWMgc3Rvcm0=', 'name': 'geomagnetic storm'},
#     {'id': 'Z2VvbWFnbmV0aWPCoG9ic2VydmF0b3J5',
#      'name': 'geomagnetic\xa0observatory'},
#     {'id': 'Z2VvbWFnbmV0aXNt', 'name': 'geomagnetism'},
#     {'id': 'Z2VvcGh5c2ljYWwgZGF0YQ==', 'name': 'geophysical data'},
#     {'id': 'Z2Vvc2NpbWw=', 'name': 'geosciml'},
#     {'id': 'Z2VvdGhlcm1hbCBlbmVyZ3k=', 'name': 'geothermal energy'},
#     {'id': 'Z2VvdGhlcm1hbCBlbmVyZ3kgcHJvZHVjdGlvbg==',
#      'name': 'geothermal energy production'},
#     {'id': 'Z2VvdGhlcm1hbCBpbmR1c3RyaWFsIGRhdGE=',
#      'name': 'geothermal industrial data'},
#     {'id': 'Z2VvdGlmZg==', 'name': 'geotiff'},
#     {'id': 'Z2Z6', 'name': 'gfz'},
#     {'id': 'Z2xvYmFsIG1vZGVs', 'name': 'global model'},
#     {'id': 'Z25zcw==', 'name': 'gnss'},
#     {'id': 'Z25zcyBnZW9qc29uIHByb2R1Y3Rz', 'name': 'gnss geojson products'},
#     {'id': 'Z25zcyBnZW9qc29uIHJpbmV4', 'name': 'gnss geojson rinex'},
#     {'id': 'Z25zcyByaW5leCBtZXRhZGF0YQ==', 'name': 'gnss rinex metadata'},
#     {'id': 'Z25zcyBzdGF0aW9u', 'name': 'gnss station'},
#     {'id': 'Z25zcyBzdGF0aW9uIHZlbG9jaXRpZXM=',
#      'name': 'gnss station velocities'},
#     {'id': 'Z25zcyBzdHJhaW4gcmF0ZXM=', 'name': 'gnss strain rates'},
#     {'id': 'Z3Jhdml0eSBkYXRh', 'name': 'gravity data'},
#     {'id': 'Z3JvdW5kIG1vdGlvbg==', 'name': 'ground motion'},
#     {'id': 'Z3JvdW5kIG1vdGlvbiBwYXJhbWV0ZXJz',
#      'name': 'ground motion parameters'},
#     {'id': 'Z3JvdW5kIHN0cmVzcw==', 'name': 'ground stress'},
#     {'id': 'Z3JvdW5kIHdhdGVy', 'name': 'ground water'},
#     {'id': 'Z3JvdW5kLWJhc2Vk', 'name': 'ground-based'},
#     {'id': 'Z3JvdW5kbWFzcw==', 'name': 'groundmass'},
#     {'id': 'aGF6YXJk', 'name': 'hazard'},
#     {'id': 'aGF6YXJkIGFzc2Vzc21lbnQ=', 'name': 'hazard assessment'},
#     {'id': 'aGF6YXJkIG1hcA==', 'name': 'hazard map'},
#     {'id': 'aGF6YXJkIG1vZGVs', 'name': 'hazard model'},
#     {'id': 'aGlnaCBwcmVzc3VyZQ==', 'name': 'high pressure'},
#     {'id': 'aGlnaCB0ZW1wZXJhdHVyZQ==', 'name': 'high temperature'},
#     {'id': 'aGlzdG9yaWNhbCBlYXJ0aHF1YWtlIHN0dWRpZXM=',
#      'name': 'historical earthquake studies'},
#     {'id': 'aG9zdCBtaW5lcmFscw==', 'name': 'host minerals'},
#     {'id': 'aG90IHNwb3Rz', 'name': 'hot spots'},
#     {'id': 'aHVtaWRpdHk=', 'name': 'humidity'},
#     {'id': 'aHlkcm9jYXJib24gcHJvZHVjdGlvbiBkYXRh',
#      'name': 'hydrocarbon production data'},
#     {'id': 'aHlwb2NlbnRyYWwgZGlzdGFuY2U=', 'name': 'hypocentral distance'},
#     {'id': 'aWNnYw==', 'name': 'icgc'},
#     {'id': 'aW1hZ2Vz', 'name': 'images'},
#     {'id': 'aW1m', 'name': 'imf'},
#     {'id': 'aW1v', 'name': 'imo'},
#     {'id': 'aW1wZWRhbmNl', 'name': 'impedance'},
#     {'id': 'aW1wZWRhbmNlIHRlbnNvcg==', 'name': 'impedance tensor'},
#     {'id': 'aW5jbGluYXRpb24=', 'name': 'inclination'},
#     {'id': 'aW5kdWNlZCBzZWlzbWljaXR5IC9lYXJ0aHF1YWtlcw==',
#      'name': 'induced seismicity /earthquakes'},
#     {'id': 'aW5kdWNlZCBzZWlzbWljaXR5IC9pbmR1Y2VkIGVhcnRocXVha2Vz',
#      'name': 'induced seismicity /induced earthquakes'},
#     {'id': 'aW5mbw==', 'name': 'info'},
#     {'id': 'aW5mcmFyZWQ=', 'name': 'infrared'},
#     {'id': 'aW5mcmFzb3VuZA==', 'name': 'infrasound'},
#     {'id': 'aW5ndg==', 'name': 'ingv'},
#     {'id': 'aW5qZWN0aW9uIGluZHVzdHJpYWwgZGF0YQ==',
#      'name': 'injection industrial data'},
#     {'id': 'aW5zYXI=', 'name': 'insar'},
#     {'id': 'aW5zcGlyZTpnZQ==', 'name': 'inspire:ge'},
#     {'id': 'aW5zcGlyZTptcg==', 'name': 'inspire:mr'},
#     {'id': 'aW50ZXJmZXJvZ3JhbQ==', 'name': 'interferogram'},
#     {'id': 'aW50ZXJmZXJvZ3JhbXM=', 'name': 'interferograms'},
#     {'id': 'aW50ZXJmZXJvbWV0cnk=', 'name': 'interferometry'},
#     {'id': 'aW50ZXJwbGFuZXRhcnkgbWFnbmV0aWMgZmllbGQ=',
#      'name': 'interplanetary magnetic field'},
#     {'id': 'aW51bmRhdGlvbg==', 'name': 'inundation'},
#     {'id': 'aW9ub3NwaGVyZQ==', 'name': 'ionosphere'},
#     {'id': 'aXBncA==', 'name': 'ipgp'},
#     {'id': 'aXJwaW5pYQ==', 'name': 'irpinia'},
#     {'id': 'aXJwaW5pYSBuZWFyIGZhdWx0IG9ic2VydmF0b3J5',
#      'name': 'irpinia near fault observatory'},
#     {'id': 'aXNvdG9wZSBnZW9jaGVtaXN0cnk=', 'name': 'isotope geochemistry'},
#     {'id': 'am95bmVyLWJvb3JlIGRpc3RhbmNl', 'name': 'joyner-boore distance'},
#     {'id': 'a29lcmk=', 'name': 'koeri'},
#     {'id': 'bGFib3JhdG9yeSBkYXRh', 'name': 'laboratory data'},
#     {'id': 'bGFuZHNsaWRlIGRlcG9zaXQ=', 'name': 'landslide deposit'},
#     {'id': 'bGFuZHNsaWRlIHNjYXI=', 'name': 'landslide scar'},
#     {'id': 'bGFuemFyb3Rl', 'name': 'lanzarote'},
#     {'id': 'bGF2YSBmbG93', 'name': 'lava flow'},
#     {'id': 'bGF2YSBtb25pdG9yaW5n', 'name': 'lava monitoring'},
#     {'id': 'bGl0aG9zcGhlcmU=', 'name': 'lithosphere'},
#     {'id': 'bGl0aG9zcGhlcmUsIGFzdGhlbm9zcGhlcmU=',
#      'name': 'lithosphere, asthenosphere'},
#     {'id': 'bG11', 'name': 'lmu'},
#     {'id': 'bG9jYWwgdGVtcGVyYXR1cmU=', 'name': 'local temperature'},
#     {'id': 'bG9uZyB0ZXJtIGNvbnRpbnVvdXMgdGltZXNlcmllcw==',
#      'name': 'long term continuous timeseries'},
#     {'id': 'bG9z', 'name': 'los'},
#     {'id': 'bG9zIHZlcnNvcg==', 'name': 'los versor'},
#     {'id': 'bWFjcm9zZWlzbWlj', 'name': 'macroseismic'},
#     {'id': 'bWFjcm9zZWlzbWljIGluZm9ybWF0aW9u',
#      'name': 'macroseismic information'},
#     {'id': 'bWFjcm9zZWlzbWljIGludGVuc2l0eQ==',
#      'name': 'macroseismic intensity'},
#     {'id': 'bWFjcm9zZWlzbW9sb2d5', 'name': 'macroseismology'},
#     {'id': 'bWFnbmV0aWMgZGF0YSBkZWZpbml0aXZl',
#      'name': 'magnetic data definitive'},
#     {'id': 'bWFnbmV0aWMgZGF0YSBwcm92aXNpb25hbA==',
#      'name': 'magnetic data provisional'},
#     {'id': 'bWFnbmV0aWMgZmllbGQ=', 'name': 'magnetic field'},
#     {'id': 'bWFnbmV0aWMgbWluZXJhbG9neQ==', 'name': 'magnetic mineralogy'},
#     {'id': 'bWFnbmV0aWMgbW9kZWw=', 'name': 'magnetic model'},
#     {'id': 'bWFnbmV0aWMgcmVtYW5lbmNl', 'name': 'magnetic remanence'},
#     {'id': 'bWFnbmV0aWMgc3VydmV5', 'name': 'magnetic survey'},
#     {'id': 'bWFnbmV0aWMgc3VzY2VwdGliaWxpdHk=',
#      'name': 'magnetic susceptibility'},
#     {'id': 'bWFnbmV0aW9zdHJhdGlncmFwaHk=', 'name': 'magnetiostratigraphy'},
#     {'id': 'bWFnbmV0aXNt', 'name': 'magnetism'},
#     {'id': 'bWFnbmV0b3NwaGVyZQ==', 'name': 'magnetosphere'},
#     {'id': 'bWFnbmV0b3RlbGx1cmljIGRhdGE=', 'name': 'magnetotelluric data'},
#     {'id': 'bWFnbmV0b3RlbGx1cmljcw==', 'name': 'magnetotellurics'},
#     {'id': 'bWFnbml0dWRl', 'name': 'magnitude'},
#     {'id': 'bWFpbiBmaWVsZA==', 'name': 'main field'},
#     {'id': 'bWFqb3IgZWxlbWVudA==', 'name': 'major element'},
#     {'id': 'bWFqb3IgZWxlbWVudCBjb21wb3NpdGlvbg==',
#      'name': 'major element composition'},
#     {'id': 'bWFw', 'name': 'map'},
#     {'id': 'bWFwcGVkZmVhdHVyZQ==', 'name': 'mappedfeature'},
#     {'id': 'bWFybWFyYQ==', 'name': 'marmara'},
#     {'id': 'bWFybWFyYSBuZWFyIGZhdWx0IG9ic2VydmF0b3J5',
#      'name': 'marmara near fault observatory'},
#     {'id': 'bWF0ZXJpYWwgcHJvcGVydHk=', 'name': 'material property'},
#     {'id': 'bWF4aW11bSBpbnVuZGF0aW9uIGhpZ2g=',
#      'name': 'maximum inundation high'},
#     {'id': 'bWVhbiB2ZWxvY2l0eQ==', 'name': 'mean velocity'},
#     {'id': 'bWVhc3VyZW1lbnQ=', 'name': 'measurement'},
#     {'id': 'bWVhc3VyZW1lbnQgcXVhbGl0eQ==', 'name': 'measurement quality'},
#     {'id': 'bWVsdCBpbmNsdXNpb24=', 'name': 'melt inclusion'},
#     {'id': 'bWV0YWRhdGE=', 'name': 'metadata'},
#     {'id': 'bWV0ZW8gcGFyYW1ldGVy', 'name': 'meteo parameter'},
#     {'id': 'bWV0ZW8gcGFyYW1ldGVycyBhdCBjbzIgc2l0ZQ==',
#      'name': 'meteo parameters at co2 site'},
#     {'id': 'bWV0cmlj', 'name': 'metric'},
#     {'id': 'bWV0cmljcw==', 'name': 'metrics'},
#     {'id': 'bWljcm9ncmFwaA==', 'name': 'micrograph'},
#     {'id': 'bWljcm9waHlzaWNhbCBkZWZvcm1hdGlvbiBwcm9jZXNz',
#      'name': 'microphysical deformation process'},
#     {'id': 'bWljcm9wcm9iZQ==', 'name': 'microprobe'},
#     {'id': 'bWljcm9zdHJ1Y3R1cmUgYW5kIHJvY2sgc3RydWN0dXJl',
#      'name': 'microstructure and rock structure'},
#     {'id': 'bWlo', 'name': 'mih'},
#     {'id': 'bWluZQ==', 'name': 'mine'},
#     {'id': 'bWluZSBpbmR1c3RyaWFsIGRhdGE=', 'name': 'mine industrial data'},
#     {'id': 'bWluZXJhbA==', 'name': 'mineral'},
#     {'id': 'bWluZXJhbCBjaGVtaXN0cnk=', 'name': 'mineral chemistry'},
#     {'id': 'bWluZXJhbCBjb21wb3NpdGlvbg==', 'name': 'mineral composition'},
#     {'id': 'bWluaXNlZWQ=', 'name': 'miniseed'},
#     {'id': 'bW9kZWw=', 'name': 'model'},
#     {'id': 'bW9kZWwgaW5kZXg=', 'name': 'model index'},
#     {'id': 'bW9kZWwgcGFyYW1ldGVy', 'name': 'model parameter'},
#     {'id': 'bW9tZW50IHRlbnNvcg==', 'name': 'moment tensor'},
#     {'id': 'bW91bnRhaW4=', 'name': 'mountain'},
#     {'id': 'bXNlZWQ=', 'name': 'mseed'},
#     {'id': 'bXVsdGlsb29r', 'name': 'multilook'},
#     {'id': 'bXVsdGlzZXJ2aWNl', 'name': 'multiservice'},
#     {'id': 'bXVsdGl0bXBvcmFs', 'name': 'multitmporal'},
#     {'id': 'bmF0dXJhbCBkaXNhc3Rlcg==', 'name': 'natural disaster'},
#     {'id': 'bmF0dXJhbCBoYXphcmQgb3IgZGlzYXN0ZXI=',
#      'name': 'natural hazard or disaster'},
#     {'id': 'bmF0dXJhbCBzZWlzbWljaXR5IC9lYXJ0aHF1YWtlcw==',
#      'name': 'natural seismicity /earthquakes'},
#     {'id': 'bmF0dXJhbCBzZWlzbWljaXR5IC9uYXR1cmFsIGVhcnRocXVha2Vz',
#      'name': 'natural seismicity /natural earthquakes'},
#     {'id': 'bmF2aWdhdGlvbg==', 'name': 'navigation'},
#     {'id': 'bmVhbQ==', 'name': 'neam'},
#     {'id': 'bmVhbXRobTE4', 'name': 'neamthm18'},
#     {'id': 'bmVhciBmYXVsdCBvYnNlcnZhdG9yaWVz',
#      'name': 'near fault observatories'},
#     {'id': 'bmZv', 'name': 'nfo'},
#     {'id': 'bmllcA==', 'name': 'niep'},
#     {'id': 'bm9h', 'name': 'noa'},
#     {'id': 'bm9yc2Fy', 'name': 'norsar'},
#     {'id': 'bnRp', 'name': 'nti'},
#     {'id': 'b2JzZXJ2YXRvcnk=', 'name': 'observatory'},
#     {'id': 'b2Rj', 'name': 'odc'},
#     {'id': 'b2lsL2dhcyBwcm9kdWN0aW9u', 'name': 'oil/gas production'},
#     {'id': 'cGFsZW9pbnRlbnNpdHk=', 'name': 'paleointensity'},
#     {'id': 'cGFsZW9tYWduZXRpc20=', 'name': 'paleomagnetism'},
#     {'id': 'cGFydGljbGU=', 'name': 'particle'},
#     {'id': 'cGFydGljbGVz', 'name': 'particles'},
#     {'id': 'cGRjcw==', 'name': 'pdcs'},
#     {'id': 'cGdh', 'name': 'pga'},
#     {'id': 'cGdk', 'name': 'pgd'},
#     {'id': 'cGd2', 'name': 'pgv'},
#     {'id': 'cGhhc2U=', 'name': 'phase'},
#     {'id': 'cGl0b24gZGUgbGEgZm91cm5haXNl', 'name': 'piton de la fournaise'},
#     {'id': 'cGxhc3RpYyBkZWZvcm1hdGlvbg==', 'name': 'plastic deformation'},
#     {'id': 'cGxhdGUgdGVjdG9uaWNz', 'name': 'plate tectonics'},
#     {'id': 'cG9sYXJpdHkgcmV2ZXJzYWxz', 'name': 'polarity reversals'},
#     {'id': 'cG9wdWxhdGlvbg==', 'name': 'population'},
#     {'id': 'cG9yZSBuZXR3b3JrIGFuZCBwb3Jvc2l0eQ==',
#      'name': 'pore network and porosity'},
#     {'id': 'cG9zaXRpb24=', 'name': 'position'},
#     {'id': 'cG93ZXI=', 'name': 'power'},
#     {'id': 'cHJvYmFiaWxpc3RpYyBtYXA=', 'name': 'probabilistic map'},
#     {'id': 'cHJvYmFiaWxpdHk=', 'name': 'probability'},
#     {'id': 'cHJvZHVjdHM=', 'name': 'products'},
#     {'id': 'cHM=', 'name': 'ps'},
#     {'id': 'cHlyb2NsYXN0aWMgZGVuc2l0eSBjdXJyZW50cw==',
#      'name': 'pyroclastic density currents'},
#     {'id': 'cXVpZXQgZGF5', 'name': 'quiet day'},
#     {'id': 'cmFkYXI=', 'name': 'radar'},
#     {'id': 'cmFkYXIgZ2VvbWV0cnk=', 'name': 'radar geometry'},
#     {'id': 'cmFkb24gY29uY2VudHJhdGlvbg==', 'name': 'radon concentration'},
#     {'id': 'cmFkb24gZGVjYXkgY291bnRz', 'name': 'radon decay counts'},
#     {'id': 'cmFkb24gc3RhdGlvbnM=', 'name': 'radon stations'},
#     {'id': 'cmFpbg==', 'name': 'rain'},
#     {'id': 'cmFrZQ==', 'name': 'rake'},
#     {'id': 'cmFuZ2UgY2hhbmdl', 'name': 'range change'},
#     {'id': 'cmFwaWQgbWFnbmV0aWMgdmFyaWF0aW9ucw==',
#      'name': 'rapid magnetic variations'},
#     {'id': 'cmVhbCB0aW1l', 'name': 'real time'},
#     {'id': 'cmVhbCB0aW1lIG1hZ25ldGljIGRhdGE=',
#      'name': 'real time magnetic data'},
#     {'id': 'cmVnaW9uIG5hbWU=', 'name': 'region name'},
#     {'id': 'cmVtYXJrYWJsZSBldmVudA==', 'name': 'remarkable event'},
#     {'id': 'cmVtb3RlIHNlbnNpbmc=', 'name': 'remote sensing'},
#     {'id': 'cmVtb3RlLXNlbnNpbmc=', 'name': 'remote-sensing'},
#     {'id': 'cmVwb3J0', 'name': 'report'},
#     {'id': 'cmVzZWFyY2ggZW52aXJvbm1lbnQ=', 'name': 'research environment'},
#     {'id': 'cmVzZXJ2b2lyIGltcG91bmRtZW50', 'name': 'reservoir impoundment'},
#     {'id': 'cmVzZXJ2b2lyIGluZHVzdHJpYWwgZGF0YQ==',
#      'name': 'reservoir industrial data'},
#     {'id': 'cmVzaWY=', 'name': 'resif'},
#     {'id': 'cmVzcG9uc2Ugc3BlY3RydW0=', 'name': 'response spectrum'},
#     {'id': 'cmV1bmlvbg==', 'name': 'reunion'},
#     {'id': 'cmluZXg=', 'name': 'rinex'},
#     {'id': 'cmluZXggZ25zcyBtZXRhZGF0YQ==', 'name': 'rinex gnss metadata'},
#     {'id': 'cm9jaw==', 'name': 'rock'},
#     {'id': 'cm9jayBtYWduZXRpc20=', 'name': 'rock magnetism'},
#     {'id': 'cm9jayBtZWNoYW5pY2FsIHRlc3Rpbmc=',
#      'name': 'rock mechanical testing'},
#     {'id': 'cm9ja3M=', 'name': 'rocks'},
#     {'id': 'cnVuLXVw', 'name': 'run-up'},
#     {'id': 'cnVudXA=', 'name': 'runup'},
#     {'id': 'cnVwdHVyZSBkaXN0YW5jZQ==', 'name': 'rupture distance'},
#     {'id': 'c2FtcGxlcw==', 'name': 'samples'},
#     {'id': 'c2FuIG1pZ3VlbA==', 'name': 'san miguel'},
#     {'id': 'c2FuZGJveCBhcHBhcmF0dXM=', 'name': 'sandbox apparatus'},
#     {'id': 'c2Fy', 'name': 'sar'},
#     {'id': 'c2F0ZWxsaXRl', 'name': 'satellite'},
#     {'id': 'c2F0ZWxsaXRlIGRhdGE=', 'name': 'satellite data'},
#     {'id': 'c2Jhcw==', 'name': 'sbas'},
#     {'id': 'c2VhbGV2ZWxz', 'name': 'sealevels'},
#     {'id': 'c2VjdWxhciB2YXJpYXRpb24=', 'name': 'secular variation'},
#     {'id': 'c2Vk', 'name': 'sed'},
#     {'id': 'c2Vpc21pYyBjYXRhbG9n', 'name': 'seismic catalog'},
#     {'id': 'c2Vpc21pYyBoYXphcmQ=', 'name': 'seismic hazard'},
#     {'id': 'c2Vpc21pYyBoYXphcmQgbW9kZWw=', 'name': 'seismic hazard model'},
#     {'id': 'c2Vpc21pYyByaXNr', 'name': 'seismic risk'},
#     {'id': 'c2Vpc21pYyBzb3VyY2U=', 'name': 'seismic source'},
#     {'id': 'c2Vpc21pYyBzdGF0aW9u', 'name': 'seismic station'},
#     {'id': 'c2Vpc21pYyB3YXZlZm9ybQ==', 'name': 'seismic waveform'},
#     {'id': 'c2Vpc21pYyB3YXZlcyBwcm9wYWdhdGlvbg==',
#      'name': 'seismic waves propagation'},
#     {'id': 'c2Vpc21pY2l0eQ==', 'name': 'seismicity'},
#     {'id': 'c2Vpc21vZmF1bHRz', 'name': 'seismofaults'},
#     {'id': 'c2Vpc21vZ2VuaWMgZmF1bHQ=', 'name': 'seismogenic fault'},
#     {'id': 'c2Vpc21vZ2VuaWMgZmF1bHRz', 'name': 'seismogenic faults'},
#     {'id': 'c2Vpc21vZ2VuaWMgc291cmNl', 'name': 'seismogenic source'},
#     {'id': 'c2Vpc21vZ2VuaWMgc291cmNlcw==', 'name': 'seismogenic sources'},
#     {'id': 'c2Vpc21vZ2VuaWMgem9uZQ==', 'name': 'seismogenic zone'},
#     {'id': 'c2Vpc21vZ2VuaWNlIHpvbmVz', 'name': 'seismogenice zones'},
#     {'id': 'c2Vpc21vbG9neQ==', 'name': 'seismology'},
#     {'id': 'c2VudGluZWw=', 'name': 'sentinel'},
#     {'id': 'c2VyYQ==', 'name': 'sera'},
#     {'id': 'c2Zlcmlj', 'name': 'sferic'},
#     {'id': 'c2hha2VtYXA=', 'name': 'shakemap'},
#     {'id': 'c2hhcmU=', 'name': 'share'},
#     {'id': 'c2hlYXI=', 'name': 'shear'},
#     {'id': 'c2hlYXIgd2F2ZSB2ZWxvY2l0eQ==', 'name': 'shear wave velocity'},
#     {'id': 'c2xhYg==', 'name': 'slab'},
#     {'id': 'c2xpcCByYXRl', 'name': 'slip rate'},
#     {'id': 'c29mdHdhcmUgY2F0YWxvZw==', 'name': 'software catalog'},
#     {'id': 'c29sYXIgY3ljbGU=', 'name': 'solar cycle'},
#     {'id': 'c29sYXIgZmxhcmU=', 'name': 'solar flare'},
#     {'id': 'c29sYXIgZmxhcmUgZWZmZWN0', 'name': 'solar flare effect'},
#     {'id': 'c29sYXIgcXVpZXQ=', 'name': 'solar quiet'},
#     {'id': 'c29sYXIgc3Rvcm0=', 'name': 'solar storm'},
#     {'id': 'c291cmNlIHBhcmFtZXRlcnM=', 'name': 'source parameters'},
#     {'id': 'c3BhY2Ugd2VhdGhlcg==', 'name': 'space weather'},
#     {'id': 'c3BhY2Utd2VhdGhlcg==', 'name': 'space-weather'},
#     {'id': 'c3BhdGlhbCBwcm9iYWJpbGl0eSBhbmFseXNpcw==',
#      'name': 'spatial probability analysis'},
#     {'id': 'c3BhdGlhbCBwcm9iYWJpbGl0eSBtYXBz',
#      'name': 'spatial probability maps'},
#     {'id': 'c3BlY3RyYQ==', 'name': 'spectra'},
#     {'id': 'c3BlY3RyYWwgcmFkaWFuY2U=', 'name': 'spectral radiance'},
#     {'id': 'c3BlY3RyYWwgcmFkaWFuY2UgZGlmZmVyZW5jZQ==',
#      'name': 'spectral radiance difference'},
#     {'id': 'c3BlY3Ryb3Njb3B5', 'name': 'spectroscopy'},
#     {'id': 'c3BoZXJpY2FsIGhhcm1vbmljcw==', 'name': 'spherical harmonics'},
#     {'id': 'c3RhdGlvbg==', 'name': 'station'},
#     {'id': 'c3RhdGlvbiBpbmZvcm1hdGlvbg==', 'name': 'station information'},
#     {'id': 'c3RhdGlvbnM=', 'name': 'stations'},
#     {'id': 'c3RhdGlvbnhtbA==', 'name': 'stationxml'},
#     {'id': 'c3RhdGlvbnhtbCBtb2RlbGluZw==', 'name': 'stationxml modeling'},
#     {'id': 'c3RyYWlu', 'name': 'strain'},
#     {'id': 'c3RyYWlubWV0ZXI=', 'name': 'strainmeter'},
#     {'id': 'c3RyZXNzLXN0cmFpbiBiZWhhdmlvcg==',
#      'name': 'stress-strain behavior'},
#     {'id': 'c3RyaWtl', 'name': 'strike'},
#     {'id': 'c3Ryb21ib2xp', 'name': 'stromboli'},
#     {'id': 'c3ViZHVjdGlvbg==', 'name': 'subduction'},
#     {'id': 'c3ViZHVjdGlvbiBmYXVsdA==', 'name': 'subduction fault'},
#     {'id': 'c3ViZHVjdGlvbiBmYXVsdHM=', 'name': 'subduction faults'},
#     {'id': 'c3VibWFyaW5lIGxhbmRzbGlkZQ==', 'name': 'submarine landslide'},
#     {'id': 'c3Vic2lkZW5jZQ==', 'name': 'subsidence'},
#     {'id': 'c3Vic2lkZW5jZSBhbmQgdXBsaWZ0', 'name': 'subsidence and uplift'},
#     {'id': 'c3Vic3Rvcm0=', 'name': 'substorm'},
#     {'id': 'c3VkZGVuIGNvbW1lbmNlbWVudA==', 'name': 'sudden commencement'},
#     {'id': 'c3VkZGVuIGltcHVsc2U=', 'name': 'sudden impulse'},
#     {'id': 'c3VkZGVuIHN0b3JtIGNvbW1lbmNlbWVudA==',
#      'name': 'sudden storm commencement'},
#     {'id': 'c3VsZnVyIGRpb3hpZGU=', 'name': 'sulfur dioxide'},
#     {'id': 'c3lzdGVtIGdlb21ldHJ5IGNvbnZlcnNpb24=',
#      'name': 'system geometry conversion'},
#     {'id': 'dGFib28=', 'name': 'taboo'},
#     {'id': 'dGNzIGFo', 'name': 'tcs ah'},
#     {'id': 'dGVtcGVyYXR1cmU=', 'name': 'temperature'},
#     {'id': 'dGVwaHJhIGZhbGxvdXQ=', 'name': 'tephra fallout'},
#     {'id': 'dGVycmFzYXIteA==', 'name': 'terrasar-x'},
#     {'id': 'dGV4dHVyZQ==', 'name': 'texture'},
#     {'id': 'dGhlcm1hbCBhbm9tYWxpZXM=', 'name': 'thermal anomalies'},
#     {'id': 'dGhlcm1hbCBzdGF0ZQ==', 'name': 'thermal state'},
#     {'id': 'dGhpbiBzZWN0aW9u', 'name': 'thin section'},
#     {'id': 'dGlkZSBnYXVnZQ==', 'name': 'tide gauge'},
#     {'id': 'dGlsdA==', 'name': 'tilt'},
#     {'id': 'dGlsdG1ldGVy', 'name': 'tiltmeter'},
#     {'id': 'dGltZSBzZXJpZXM=', 'name': 'time series'},
#     {'id': 'dGltZXNlcmllcw==', 'name': 'timeseries'},
#     {'id': 'dGlwcGVyIHZlY3Rvcg==', 'name': 'tipper vector'},
#     {'id': 'dG9wb2dyYXBoeQ==', 'name': 'topography'},
#     {'id': 'dG9yc2lvbg==', 'name': 'torsion'},
#     {'id': 'dHJhY2UgZWxlbWVudHM=', 'name': 'trace elements'},
#     {'id': 'dHJhbnNmZXIgZnVuY3Rpb24=', 'name': 'transfer function'},
#     {'id': 'dHJpZ2dlciBtZWNoYW5pc20=', 'name': 'trigger mechanism'},
#     {'id': 'dHN1bWFwcy1uZWFt', 'name': 'tsumaps-neam'},
#     {'id': 'dHN1bmFtaQ==', 'name': 'tsunami'},
#     {'id': 'dHN1bmFtaSBlZmZlY3Rz', 'name': 'tsunami effects'},
#     {'id': 'dHN1bmFtaSBoYXphcmQ=', 'name': 'tsunami hazard'},
#     {'id': 'dHN1bmFtaSBpbnRlbnNpdHkgbWVhc3VyZQ==',
#      'name': 'tsunami intensity measure'},
#     {'id': 'dHN1bmFtaWRhdGE=', 'name': 'tsunamidata'},
#     {'id': 'dWli', 'name': 'uib'},
#     {'id': 'dW5jb252ZW50aW9uYWwgaHlkcm9jYXJib24gZXh0cmFjdGlvbg==',
#      'name': 'unconventional hydrocarbon extraction'},
#     {'id': 'dW5kZXJncm91bmQgZ2FzIHN0b3JhZ2U=',
#      'name': 'underground gas storage'},
#     {'id': 'dW5kZXJncm91bmQgbWluaW5n', 'name': 'underground mining'},
#     {'id': 'dW53cmFwcGVk', 'name': 'unwrapped'},
#     {'id': 'dmFhYyAtIHZvbGNhbmljIGFzaCBhZHZpc29yaWVzIGNlbnRlcnM=',
#      'name': 'vaac - volcanic ash advisories centers'},
#     {'id': 'dmFsYWlz', 'name': 'valais'},
#     {'id': 'dmFyaW9tZXRlcg==', 'name': 'variometer'},
#     {'id': 'dmVsb2NpdGllcw==', 'name': 'velocities'},
#     {'id': 'dmVsb2NpdHk=', 'name': 'velocity'},
#     {'id': 'dmVsb2NpdHkgbW9kZWw=', 'name': 'velocity model'},
#     {'id': 'dmVzaWNsZSBjcnlzdGFs', 'name': 'vesicle crystal'},
#     {'id': 'dmlzY291cyBiZWhhdmlvcg==', 'name': 'viscous behavior'},
#     {'id': 'dm9sYXRpbGUgZWxlbWVudHM=', 'name': 'volatile elements'},
#     {'id': 'dm9sY2FuaWMgYWN0aXZpdHk=', 'name': 'volcanic activity'},
#     {'id': 'dm9sY2FuaWMgYXNo', 'name': 'volcanic ash'},
#     {'id': 'dm9sY2FuaWMgZXJ1cHRpb24=', 'name': 'volcanic eruption'},
#     {'id': 'dm9sY2FuaWMgZ2Fz', 'name': 'volcanic gas'},
#     {'id': 'dm9sY2FuaWMgZ2xhc3M=', 'name': 'volcanic glass'},
#     {'id': 'dm9sY2FuaWMgaGF6YXJk', 'name': 'volcanic hazard'},
#     {'id': 'dm9sY2FuaWMgcGx1bWU=', 'name': 'volcanic plume'},
#     {'id': 'dm9sY2Fubw==', 'name': 'volcano'},
#     {'id': 'dm9sY2Fub2Vz', 'name': 'volcanoes'},
#     {'id': 'dm9sY2Fub2xvZ3k=', 'name': 'volcanology'},
#     {'id': 'dm9sdW1l', 'name': 'volume'},
#     {'id': 'dm9uYQ==', 'name': 'vona'},
#     {'id': 'dnAvdnM=', 'name': 'vp/vs'},
#     {'id': 'dnAvdnMgcmF0aW8=', 'name': 'vp/vs ratio'},
#     {'id': 'dnJhbmNlYQ==', 'name': 'vrancea'},
#     {'id': 'dnVsY2Fubw==', 'name': 'vulcano'},
#     {'id': 'dnVsbmVyYWJpbGl0eSBjdXJ2ZQ==', 'name': 'vulnerability curve'},
#     {'id': 'd2FzdGV3YXRlciBpbmplY3Rpb24=', 'name': 'wastewater injection'},
#     {'id': 'd2F0ZXIgbGV2ZWw=', 'name': 'water level'},
#     {'id': 'd2F0ZXIgcXVhbGl0eSBkYXRh', 'name': 'water quality data'},
#     {'id': 'd2F2ZWZvcm0=', 'name': 'waveform'},
#     {'id': 'd2F2ZWZvcm0gbW9kZWxpbmc=', 'name': 'waveform modeling'},
#     {'id': 'd2ViIGNhbWVyYQ==', 'name': 'web camera'},
#     {'id': 'd2ViIHBsYXRmb3Jt', 'name': 'web platform'},
#     {'id': 'd2ZjYXRhbG9n', 'name': 'wfcatalog'},
#     {'id': 'd2hvbGUgcm9jayBjaGVtaXN0cnk=', 'name': 'whole rock chemistry'},
#     {'id': 'd21vIC0gd29ybGQgbWV0ZW9yb2xnaWNhbCBvcmdhbml6YXRpb24=',
#      'name': 'wmo - world meteorolgical organization'},
#     {'id': 'd29ya3NwYWNl', 'name': 'workspace'},
#     {'id': 'd29ybGQgbW9kZWw=', 'name': 'world model'},
#     {'id': 'd3JhcHBlZA==', 'name': 'wrapped'},
#     {'id': 'eC1yYXkgdG9tb2dyYXBoeQ==', 'name': 'x-ray tomography'}],
#    'name': 'keywords'},
#   {'children': [{'id': 'a6d63122-f71a-4de2-9784-ba90bf10e14b',
#      'name': 'AMRA – Analysis and Monitoring of Environmental Risk'},
#     {'id': '9d02af33-60e9-4821-94da-1df2e660fd47',
#      'name': 'Agencia Estatal Consejo Superior de Investigaciones Cientificas, CSIC'},
#     {'id': 'f1f0d808-9617-48cd-ab0b-b4037cc178e0',
#      'name': 'Agencia Estatal Consejo Superior de Investigaciones Científicas (CSIC)'},
#     {'id': 'c71f6dcf-1009-4ac4-a528-fea1c8d11016',
#      'name': 'British Geological Survey, UK Research and Innovation'},
#     {'id': 'fe60830e-27d6-45ab-8465-c17513db4b9a',
#      'name': 'Bureau de Recherches Géologiques et Minières'},
#     {'id': 'e3cf7304-94c3-4c68-9a58-6bb5643a66c4',
#      'name': 'CNR-IREA - Institute for Electromagnetic Sensing of the Environment'},
#     {'id': '99b2127d-f9e3-4ba9-b2a6-8cd8aac7c569',
#      'name': 'CNRS, ISTerre, Université Grenoble Alpes'},
#     {'id': '1b672c10-684c-405b-9733-56f8a94cd0fe',
#      'name': 'Central Mining Institute'},
#     {'id': 'caa8b9b0-84b0-4adc-98a2-2163ae0f24fd',
#      'name': 'Centre National pour la Recherche Scientifique et Technique (CNRST)'},
#     {'id': 'd55a1709-2884-4ed7-bb08-01d112c74455',
#      'name': 'Department of Geodesy, Remote Sensing and Land Offices - Government Office of the Capital City Budapest'},
#     {'id': '3312b8d9-9f2c-4a2a-8e56-a68e208a73eb',
#      'name': 'Earth Physics Observatory of Clermont-Ferrand'},
#     {'id': '8d964d34-8a1b-48f4-8f2d-78adc788de09',
#      'name': 'Ecole et Observatoire des Sciences de la Terre'},
#     {'id': '1e401aeb-5c87-4dce-8f34-a7656d9efe9a',
#      'name': 'European-Mediterranean Seismological Centre'},
#     {'id': 'a3ec990a-b4d4-460d-8258-2f2f783a1275',
#      'name': 'Federal Institute of Geosciences and Natural Resources'},
#     {'id': 'aa7eab35-e2ca-4f52-88e5-5176dd6ea1f4',
#      'name': 'Finnish Meteorological Institute'},
#     {'id': 'a0ae9540-e152-4422-ad44-36f4e4de7aed',
#      'name': 'Fondazione EUCENTRE'},
#     {'id': '37262ecf-037d-4c4b-b8ee-a061d6362a6f',
#      'name': 'GFZ German Research Centre for Geosciences'},
#     {'id': 'b9819f30-1bbd-42eb-8d8c-59e9cfc59082',
#      'name': 'Geological Survey of Denmark and Greenland'},
#     {'id': '84c22125-c398-4bad-bb14-1d229a0b2028',
#      'name': 'Geological Survey of Slovenia'},
#     {'id': 'd4432ef9-3c15-4faf-85ba-81b6e41923b1',
#      'name': 'Helmholtz-Zentrum Potsdam - Deutsches GeoForschungsZentrum (GFZ)'},
#     {'id': 'd1f1a813-e89f-4d05-9b43-2ff70d78781f',
#      'name': "INERIS, Institut National de l'Environnement Industriel et des Risques"},
#     {'id': '9440a58c-c0fe-46ce-8955-01522bd88716', 'name': 'ISTerre'},
#     {'id': '9a491d6a-28f3-41f1-9042-672a01accf61',
#      'name': 'Icelandic Meteorological Office'},
#     {'id': '80db70c4-b453-4109-9cbf-0d870e653333',
#      'name': 'Institut Cartografic i Geologic de Catalunya'},
#     {'id': '6bfd64e0-4b48-4d8a-8d82-85abe86772f4',
#      'name': 'Institute of Earth Physics of Paris'},
#     {'id': 'd7dd740d-8432-43dc-b5e0-f23eac68a079',
#      'name': 'Institute of Geophysics, Polish Academy of Sciences'},
#     {'id': '8a395d55-37af-4a06-9f7e-b429d6a973a4',
#      'name': 'Instituto Português do Mar e da Atmosfera (IPMA)'},
#     {'id': 'a829ba9b-0c8e-4d9a-ba30-5e99b2171392',
#      'name': 'Istituto Nazionale di Geofisica e Vulcanologia (INGV)'},
#     {'id': '4993a24f-2a1a-42bf-8dfe-02b6767d47f5',
#      'name': 'Istituto Nazionale di Geofisica e Vulcanologia - Centro Nazionale di Terremoti, Rome, Italy'},
#     {'id': '6c1e2cff-1c84-4198-9d02-6dde2c507e44',
#      'name': 'KOERI Kandilli Observatory and Earthquake Research Institute'},
#     {'id': '1aa00c1f-2657-4c95-8a5a-a6cab44ff070', 'name': 'Keele University'},
#     {'id': '68ad8e26-a394-446e-93ea-3d19dea6c201',
#      'name': 'Koninklijk Nederlands Meteorologisch Instituut'},
#     {'id': '90e5eab4-d1b8-4732-b0e4-b124353a6d34',
#      'name': 'Lantmäteriet, Sweden'},
#     {'id': '4fd42a76-5b74-4fa8-9864-c021026e5b0c',
#      'name': 'Ludwig-Maximilians-Universität München'},
#     {'id': '9d7d057c-90f9-4f25-85b5-31b1e0c8c910',
#      'name': 'Luleå University of Technology'},
#     {'id': '316b2d3d-96f3-447e-8ac3-ecb35658f9a6',
#      'name': 'Middle East Technical University (METU)'},
#     {'id': 'f86b1530-7ed9-4ced-80aa-19a2ab1ecc7f',
#      'name': 'NIEP National Institute for Earth Physics'},
#     {'id': 'bbf735c6-e753-4acb-a198-a8888d4ec522',
#      'name': 'NOA National Observatory of Athens'},
#     {'id': '18f42dc9-8098-49e4-b21c-63523b041ba4',
#      'name': 'National Institute of Geophysics and Volcanology'},
#     {'id': 'e35313da-390a-469a-8f5f-d075562ae2eb',
#      'name': 'National Institute of Meteorology (INM)'},
#     {'id': '8ad29649-8747-4b2f-9762-76f4cab5e106',
#      'name': 'National Observatory of Athens (NOA)'},
#     {'id': 'c3e2262e-213b-4d92-9d45-a4aadde005c1',
#      'name': 'Norwegian Geotechnical Institute (NGI)'},
#     {'id': '6ae46f63-9623-4d6c-829e-475e0ffc6c9a',
#      'name': 'Observatoire de la Côte d’Azur'},
#     {'id': '1f56e15b-0500-44da-8076-29b77580b574', 'name': 'Q-con GmbH'},
#     {'id': 'd7ca8d82-a001-4464-8334-05f21ff25100',
#      'name': 'RESIF Data Center'},
#     {'id': '9d61c55a-33b7-4c41-8337-a7961c320a48',
#      'name': 'Royal Observatory of Belgium'},
#     {'id': '2f4009a8-f94c-4ad2-9277-d79f491787aa',
#      'name': 'Réseau sismologique & géodésique français'},
#     {'id': '83b34f0d-570a-4e31-8ff3-1b64d0e92f71',
#      'name': 'STIFTELSEN NORSAR'},
#     {'id': '77abb715-05c0-4e54-a6ce-89a4fc045b44',
#      'name': 'St.Galler Stadtwerke'},
#     {'id': 'bc6caa4f-2a07-4939-a8aa-e22f3d925316',
#      'name': 'Swiss Seismological Service at the Federal Institute of Technology Zurich'},
#     {'id': '402333bc-efd0-4c84-a4e6-9d08be3e0e0b',
#      'name': 'Universiteit Utrecht'},
#     {'id': '369f63f0-2e28-46ab-8172-b20de839ec69',
#      'name': 'University College London (UCL)'},
#     {'id': 'bfcc779c-0a40-4ee5-879a-6a6f07bcc4f3',
#      'name': 'University of Barcelona (UB)'},
#     {'id': '000ba690-7327-4015-b83e-ce030c3fd9ac',
#      'name': 'University of Beira Interior'},
#     {'id': '0c2f3e23-1544-4f6d-85d2-836547b5e8ca',
#      'name': 'University of Bergen'},
#     {'id': '0f70749d-c9cd-410a-8d9c-7ea044574eee',
#      'name': 'University of Leeds'},
#     {'id': 'd342cd8e-caf0-4a20-b07e-dcec35ff308f',
#      'name': 'University of Oulu (UoO)'},
#     {'id': '2c89f24f-5ab3-4826-806a-ff01df0d0304',
#      'name': 'Università degli Studi di Napoli Federico II'},
#     {'id': 'f6defd25-bfd0-4136-9083-7561a0963647',
#      'name': 'Université Grenoble Alpes'},
#     {'id': 'a6c20a01-fb82-4b4a-9245-4ac4f346c46e',
#      'name': 'Vlaams Insitituut voor de Zee vzw.'},
#     {'id': 'd3d5a52c-d1c5-4e17-bec3-7658bfa70efb',
#      'name': 'École et Observatoire des Sciences de la Terre, Strasbourg'}],
#    'name': 'organisations'},
#   {'children': [{'id': 'ea87ca33-669f-4d83-b3aa-35165b7649ac',
#      'name': 'RiskMap'},
#     {'id': 'd88a1e55-2c5d-47c7-9722-5df3b6dc6ecf',
#      'name': 'StressFieldModelling'},
#     {'id': '24658408-90d4-407f-8625-5e29ca72fb98', 'name': 'WaveformQuality'},
#     {'id': '3578fc81-16d9-4f34-91da-595de8ac37e8',
#      'name': 'RadarInterferometry'},
#     {'id': '6475d4cf-454e-4ff1-b6d4-bbde67618342', 'name': 'Borehole'},
#     {'id': '7e3cd527-4d61-46c6-8fda-975ab08316cd',
#      'name': 'SourceAndShakingParametersEstimation'},
#     {'id': '7849ff6a-88f7-48c9-ac00-1ad5eadd6c68',
#      'name': 'VolcanologicalData'},
#     {'id': '0deefdb3-8ec2-4ac7-9b19-584b40e3a3f3', 'name': 'Geohazards'},
#     {'id': '011884c0-4b95-4730-b0b5-5381484baeba', 'name': 'TiltmeterStation'},
#     {'id': 'b89464da-1802-4b3c-9b38-46386dd6035c',
#      'name': 'AnalogueModellingResults'},
#     {'id': 'b328b224-2b00-426a-b137-4f50567a143c', 'name': 'CO2concentration'},
#     {'id': 'd1890285-3b97-4faf-a867-00edeb2a4ba0',
#      'name': 'MagneticPaleomagneticData'},
#     {'id': '14b7dfd6-77c3-40ce-8ed1-97eb80059c84', 'name': 'DownloadTools'},
#     {'id': '8dee4a96-24a8-4dff-bb10-f6e702ea0716', 'name': 'Coalmining'},
#     {'id': '80d0070f-80e8-4f30-bb3d-4b84072445ff',
#      'name': 'SeismicParametrics'},
#     {'id': 'ed18b3c2-6f38-4fb3-945c-866533f9e551',
#      'name': 'Historicalearthquakes'},
#     {'id': '93e18e5f-fb62-4808-8e2f-223ef4966875',
#      'name': 'RockAndMeltPhysicalProperties'},
#     {'id': '5c8166e6-a18c-46e5-81f0-f347a34aba93',
#      'name': 'StrainmeterStations'},
#     {'id': '7749ee87-b707-4073-8f84-28025e15d93c', 'name': 'GeophysicalData'},
#     {'id': 'a92797ff-b7b8-42a0-905c-772b21dcf4fd', 'name': 'ETRIS_v0'},
#     {'id': 'bca9fd32-e3d6-41e7-8e82-793ee6b0ba42',
#      'name': 'Ground-basedremotesensingdata&products'},
#     {'id': '778877ae-a8da-407a-b209-5ca17004c141', 'name': 'Mine'},
#     {'id': '7578ae14-c4b4-4690-b891-c0fcfc3c643d', 'name': 'Converters'},
#     {'id': '8ccce372-c7a1-40b3-aa1a-302dcefae968', 'name': 'EMTC_v2'},
#     {'id': '5be432d5-5aed-4a1d-8d86-67963e035ef0',
#      'name': 'Volcanological-Data'},
#     {'id': '03c44363-bf95-4b76-adf7-23a88d963952', 'name': 'SeismicNetwork'},
#     {'id': 'cb908b5b-f203-4c63-8883-5ac4f0c5788f', 'name': 'SeismicWaveform'},
#     {'id': 'e9b08a30-162c-47ca-a48e-003ce4aa2699',
#      'name': 'Conventionalhydrocarbonextraction'},
#     {'id': 'bca17409-ae2c-4baa-888d-4795c1bccbeb',
#      'name': 'Studiesonearthquakes'},
#     {'id': '869ad023-87c8-4fae-92a9-933ec004249c', 'name': 'Magneticactivity'},
#     {'id': 'ee42cb06-cda9-4394-9faf-3a4f4ce64060',
#      'name': 'Crustalvelocityparameters'},
#     {'id': '9d036909-6848-4481-b340-47214e3e6ce9', 'name': 'VONA-Reports'},
#     {'id': 'e1cda391-582c-410f-8461-b744801e19d6', 'name': 'waveformquality'},
#     {'id': '15a99c4a-622f-490d-b709-2d3b541feb3c', 'name': 'Hazard'},
#     {'id': '62bd17ca-f197-4694-bca2-2273b1406feb', 'name': 'Visualizations'},
#     {'id': '0eadde7a-6261-4f19-9ada-c514021ba915',
#      'name': 'SeismologicalProducts'},
#     {'id': 'a6917dc7-348d-4c4b-b447-6058ca68ebb9', 'name': 'GeologicUnit'},
#     {'id': '2d9c2a5d-9915-460f-9b09-3f12aacd86cd', 'name': 'Hardrockmining'},
#     {'id': '358906bc-781c-489c-9536-f11605a6d2f2',
#      'name': 'HazardAndRiskAnalysis'},
#     {'id': 'b43b186f-28e9-4a04-a3d8-a16635be565e',
#      'name': 'Thermalmonitoring'},
#     {'id': 'ab45fca9-8a49-4233-aadf-e3fd4bb9d882', 'name': 'Volcanic-Reports'},
#     {'id': '36a5397e-3645-4cab-a625-f2888f742398', 'name': 'Magneticfield'},
#     {'id': '71d59c4e-d32a-4a22-9245-dd12304dc671', 'name': 'Software-catalog'},
#     {'id': 'f657b0c8-112b-4cf3-a15a-4f0f448dede9', 'name': 'Seismicwaveforms'},
#     {'id': 'e80f8546-c6a3-4fff-be4a-8cf31387d6be', 'name': 'InSAR'},
#     {'id': '0a593e8b-d106-465a-a0cb-c30674e007b3',
#      'name': 'Volcanological/petrological'},
#     {'id': 'c88c5707-77d1-42c0-978a-dcf47b3b8c0b',
#      'name': 'SusceptibilityMap'},
#     {'id': 'a4fb8dc3-a612-40ad-b9e7-62a905928f08',
#      'name': 'GNSSProductsPortal'},
#     {'id': '6432f75f-6332-48f0-8df0-67c79bb03890', 'name': 'SeismicStations'},
#     {'id': 'a9ea7acc-fbbc-4688-ae55-b4402c6312cd', 'name': 'GeochemicalData'},
#     {'id': 'db32f030-6800-45f3-a05b-329a8c74b713',
#      'name': 'TiltmeterWaveform'},
#     {'id': 'bc999e1b-819b-4cf3-b10d-4f48423bda33', 'name': 'Activefaults'},
#     {'id': '3e724ce3-d215-4676-bd42-33bbd5d84943', 'name': 'Waveformquality'},
#     {'id': '68a1bcfb-7cf2-4e68-8eee-35f4cb0e9aa9', 'name': 'StrongMotion'},
#     {'id': '70870346-fa9f-4124-a7a1-b6d479579b37',
#      'name': 'Geothermalenergyproduction'},
#     {'id': '74d502e4-222a-423d-ad98-075f88a8fe53',
#      'name': 'StrainmeterWaveforms'},
#     {'id': 'd8d9345b-d142-42e7-9504-05f969e63b3a',
#      'name': 'EarthquakeParameters'},
#     {'id': '19ead3f6-e4aa-4881-a4f8-b2e91e5f0b80', 'name': '3D/4Dmodel'},
#     {'id': '02eb1846-1b45-4f38-bf86-fb4100c500f3', 'name': 'GeochemistryData'},
#     {'id': '0223bc4d-0810-4021-9ee1-3870c594994e',
#      'name': 'Meteorologicaldata'},
#     {'id': 'fcc8715a-9930-4250-8082-a65bcc626210', 'name': 'Magnetotellurics'},
#     {'id': '0412aa34-87b6-4cef-a5a5-18987b282cce', 'name': 'DopplerRadar'},
#     {'id': '5f6b4f0b-36c1-4264-b446-c9610303fdfd', 'name': 'TideWaveform'},
#     {'id': 'c47afb74-d0ca-4123-a1e4-7d4f95ce45a7', 'name': 'Seismicstations'},
#     {'id': '55d5225e-7a76-4c7f-8a71-77c95df948ec',
#      'name': 'EarthquakeHazardAndRiskServices'},
#     {'id': 'ad7899ab-93f0-443a-a1f5-c8c700ce7c4c', 'name': 'TideStation'},
#     {'id': '05ed4ff8-cce5-4ffa-af58-8c0756cf3ff1',
#      'name': 'Radonconcentration'},
#     {'id': 'd2a2e29b-8154-40ef-8262-bab1a92b9f8a', 'name': 'EMSS21'},
#     {'id': 'ce9ce929-f91d-4583-a208-854af6db7371', 'name': 'LaboratoryData'},
#     {'id': '0c78534f-24a8-4e3b-8127-040e389ea2fb',
#      'name': 'http://vocab.nerc.ac.uk/collection/P02/current/ASLV/'},
#     {'id': 'ee65c34e-8a99-4a1e-87c8-4b53022e6314',
#      'name': 'MicroscopyTomographyData'},
#     {'id': '4f364c6f-9b6b-4ef6-8ba4-01842c22a024', 'name': 'Interferograms'},
#     {'id': '2f60771f-acaa-4c09-a6a9-7f5df39856c9', 'name': 'Geochemical-Data'},
#     {'id': '5767f016-ee89-4a0d-b9b3-1d2a7482c595',
#      'name': 'ExploratoryStatisticalAnalysis'},
#     {'id': '202762de-d1d7-4f90-9d32-5c488fc78e34',
#      'name': 'Atmosphericmonitoring'},
#     {'id': 'd48af325-78d4-457a-aabf-e2273b807fa9', 'name': 'SeismicStation'},
#     {'id': 'd9597f08-06e6-4f2f-8798-5f8fb3cb5e9e', 'name': 'NEAMTHM18'},
#     {'id': 'acb0e92f-98ef-47ea-a44f-e679661cf08d', 'name': 'Hazardmap'},
#     {'id': '75effb5c-90ca-411b-be82-97c962100a6f', 'name': 'Macroseismicdata'},
#     {'id': '4f62d7a7-6656-4b07-b26d-10f6911442a7', 'name': 'ExposureModel'},
#     {'id': '6164b443-5e1a-4ba1-a775-631ac5ecc6fa',
#      'name': 'Unconventionalhydrocarbonextraction'},
#     {'id': '75b6fe39-a64d-47cf-9ea5-1a61aab84d33',
#      'name': 'ReconstructionTools'},
#     {'id': '4b61d755-0f30-4e7e-80d6-94731c57be4e', 'name': 'SeismicWaveforms'},
#     {'id': 'a49cf32e-7ce4-4331-910a-2b354c09247e',
#      'name': 'volcanic-activity'},
#     {'id': '1bf0f3c4-532b-472b-881c-fa36e247bd9e',
#      'name': 'Saltsolutionsmining'},
#     {'id': 'c0d7b54c-7779-478e-8d1d-321d2152e10d', 'name': 'GeodeticData'},
#     {'id': '319c01a3-0296-4ebd-94fc-818386ad2420',
#      'name': 'Reservoirimpoundment'}],
#    'name': 'sciencedomains'},
#   {'children': [{'id': 'ea87ca33-669f-4d83-b3aa-35165b7649ac',
#      'name': 'RiskMap'},
#     {'id': 'd88a1e55-2c5d-47c7-9722-5df3b6dc6ecf',
#      'name': 'StressFieldModelling'},
#     {'id': '24658408-90d4-407f-8625-5e29ca72fb98', 'name': 'WaveformQuality'},
#     {'id': '3578fc81-16d9-4f34-91da-595de8ac37e8',
#      'name': 'RadarInterferometry'},
#     {'id': '6475d4cf-454e-4ff1-b6d4-bbde67618342', 'name': 'Borehole'},
#     {'id': '7e3cd527-4d61-46c6-8fda-975ab08316cd',
#      'name': 'SourceAndShakingParametersEstimation'},
#     {'id': '7849ff6a-88f7-48c9-ac00-1ad5eadd6c68',
#      'name': 'VolcanologicalData'},
#     {'id': '0deefdb3-8ec2-4ac7-9b19-584b40e3a3f3', 'name': 'Geohazards'},
#     {'id': '011884c0-4b95-4730-b0b5-5381484baeba', 'name': 'TiltmeterStation'},
#     {'id': 'b89464da-1802-4b3c-9b38-46386dd6035c',
#      'name': 'AnalogueModellingResults'},
#     {'id': 'b328b224-2b00-426a-b137-4f50567a143c', 'name': 'CO2concentration'},
#     {'id': '476b309e-7e68-4a54-b4c8-988d0c924c56', 'name': 'HazardMaps'},
#     {'id': 'd1890285-3b97-4faf-a867-00edeb2a4ba0',
#      'name': 'MagneticPaleomagneticData'},
#     {'id': '14b7dfd6-77c3-40ce-8ed1-97eb80059c84', 'name': 'DownloadTools'},
#     {'id': '8dee4a96-24a8-4dff-bb10-f6e702ea0716', 'name': 'Coalmining'},
#     {'id': '80d0070f-80e8-4f30-bb3d-4b84072445ff',
#      'name': 'SeismicParametrics'},
#     {'id': 'ed18b3c2-6f38-4fb3-945c-866533f9e551',
#      'name': 'Historicalearthquakes'},
#     {'id': '93e18e5f-fb62-4808-8e2f-223ef4966875',
#      'name': 'RockAndMeltPhysicalProperties'},
#     {'id': '5c8166e6-a18c-46e5-81f0-f347a34aba93',
#      'name': 'StrainmeterStations'},
#     {'id': '7749ee87-b707-4073-8f84-28025e15d93c', 'name': 'GeophysicalData'},
#     {'id': 'a92797ff-b7b8-42a0-905c-772b21dcf4fd', 'name': 'ETRIS_v0'},
#     {'id': 'bca9fd32-e3d6-41e7-8e82-793ee6b0ba42',
#      'name': 'Ground-basedremotesensingdata&products'},
#     {'id': '778877ae-a8da-407a-b209-5ca17004c141', 'name': 'Mine'},
#     {'id': '7578ae14-c4b4-4690-b891-c0fcfc3c643d', 'name': 'Converters'},
#     {'id': '8ccce372-c7a1-40b3-aa1a-302dcefae968', 'name': 'EMTC_v2'},
#     {'id': '5be432d5-5aed-4a1d-8d86-67963e035ef0',
#      'name': 'Volcanological-Data'},
#     {'id': '03c44363-bf95-4b76-adf7-23a88d963952', 'name': 'SeismicNetwork'},
#     {'id': 'cb908b5b-f203-4c63-8883-5ac4f0c5788f', 'name': 'SeismicWaveform'},
#     {'id': 'e9b08a30-162c-47ca-a48e-003ce4aa2699',
#      'name': 'Conventionalhydrocarbonextraction'},
# ...
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=b1ca6bf0-4f62-416a-ba1b-a05b841bdada&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-025',
#    'description': "Enables to list data items contained in the episode (dataset) as 'Seismic Network', 'Event related waveforms', 'Velocity model', 'Deformation Measurements' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. Situated in Cheshire in the NW of England, Northwich overlies Triassic Halite beds that have been industrially and extensively mined for salt since the 17th century. As a result of poor early mining practices, combined with natural and anthropogenic salt dissolution, the area has suffered from mine void collapse and large scale catastrophic surface land subsidence. This episode contains long term microgravity data obtained for the detection and monitoring of voids, and time-lapse topography data for subsidence and ground deformation records. Both datasets are from a section of the Trent and Mersey Canal that has been severely affected by subsidence and the episode is supplemented with mine plans of the area along with details of a seismic network situated to the south of the monitored canal section. A 2012 paper detailing 10 years of monitoring + canal topography data is also available.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=b1ca6bf0-4f62-416a-ba1b-a05b841bdada',
#    'id': 'b1ca6bf0-4f62-416a-ba1b-a05b841bdada',
#    'status': 0,
#    'title': 'Episode NORTHWICH: underground salt extraction cavities - dataset',
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/NORTHWICH'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=42b8cbad-3eda-42f4-bf41-95908d9225a0&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=42b8cbad-3eda-42f4-bf41-95908d9225a0&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-011',
#    'description': "Enables to list data items contained in the episode (dataset) as ‘Catalog' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. The episode describes the seismicity sequence around Monteynard dam, caused by reservoir impoundment in France. The seismic sequence, April 1962, M=5.5, April 1963, M=4.9, November 1979, M=4.5 is located is the near field of the reservoir, i.e. within 1-3 reservoir lake lengths. Monteynard reservoir situated in moderate activity seismic zone of western Alps. Initially within first few years, six earthquakes (ML higher than 3.5) occurred in quick succession in close vicinity of the reservoir (less than 15 km) thereby supporting the hypothesis of reservoir induced earthquakes at Monteynard. The first significant earthquake (M5.2) occurred near the reservoir when the reservoir was only one third full (40 m deep). The two other earthquakes (ML bigger than 4.5) in 1963 and 1979 occurred when the reservoir level peaked to its maximum value (115 m). The episode data correspond to (i) seismicity catalogues (1962,2009) around the reservoir up to a 10L distance to reservoir (L being the reservoir lake length). The users can select catalogue for seismicity either in 1L or 3L or 10L distance to lake reservoir; (ii) Yearly values for reservoir lake level are provided on the 1961-1992 period as mean, maximum and minimum values; monthly values being only available on the 1961-1964 period.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=42b8cbad-3eda-42f4-bf41-95908d9225a0',
#    'id': '42b8cbad-3eda-42f4-bf41-95908d9225a0',
#    'status': 0,
#    'title': 'Episode MONTEYNARD: water reservoir - dataset',
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/MONTEYNARD'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=7d1dabc3-c9aa-4369-a53e-0661d163ae22&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=7d1dabc3-c9aa-4369-a53e-0661d163ae22&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-045',
#    'description': "Enables to list data items contained in the episode (dataset) as ‘Catalog', 'Seismic Network', 'Event related waveforms', 'Velocity model' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. The BOIS episode contains data related to seismic activity induced by mining. In the region which is located in eastern Poland, coal is excavated by Lubelski Węgiel “Bogdnaka” mine. The mine uses longwall system and coal seams are located from 0.5 – 1.2 km below the surface. The seismicity is monitored with 12 broad-band (5s) seismometers (GeoSIG VE-53/BB). The episode started in November 2018 and remains open.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=7d1dabc3-c9aa-4369-a53e-0661d163ae22',
#    'id': '7d1dabc3-c9aa-4369-a53e-0661d163ae22',
#    'status': 0,
#    'title': 'Episode BOGDANKA: underground coal mining - dataset',
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/BOGDANKA'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=8ee6fb6e-3cbe-4e37-a55b-0c54b9778134&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=8ee6fb6e-3cbe-4e37-a55b-0c54b9778134&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-019',
#    'description': "Enables to list data items contained in the episode (dataset) as ‘Catalog', 'Seismic Network', 'Event related waveforms', 'Velocity model' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. This episode describes seismic monitoring of the initial stage of wastewater injection into a disposal well of the Val d'Agri oil field. The monitoring unraveled a low magnitude swarm induced by disposal operations that initiated just a few hours after the beginning of injection. Main objective is to provide seismic data to be analyzed with advanced techniques for a better understanding of the mechanisms of injection-linked seismicity and of physical properties of the reservoir.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=8ee6fb6e-3cbe-4e37-a55b-0c54b9778134',
#    'id': '8ee6fb6e-3cbe-4e37-a55b-0c54b9778134',
#    'status': 0,
#    'title': "Episode VAL D'AGRI FIELD: conventional hydrocarbon extraction - dataset",
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/VDF'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=afc834a3-f28b-44a9-ad29-24a4e4c6262d&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=afc834a3-f28b-44a9-ad29-24a4e4c6262d&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-039',
#    'description': "Enables to list data items contained in the episode (dataset) as ‘Catalog' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. This episode decribes the geothermal project undertaken by the city of St. Gallen (Switzerland) and operated by the St. Galler Stadtwerke was based on a large-scale 3D seismic survey in 2010. The survey led to drilling of the geothermal well, “St. Gallen GT-1”, to a measured depth of 4450 m across Paleozoic / Mesozoic rock formations as well as extensive scientific and technical analysis, and well completion aimed at geothermal use. The area has additionally been instrumented with a micro-seismic array operated since 2012 by the Swiss Seismic Survey (SED). After complications occurred during well stimulation and testing in July 2013 (a gas kick and seismic events up to ML 3.5 as a consequence of killing the well) the project was temporarily stopped. In October 2013 the project was resumed with a modified drill stem test producing gas and water and collection of a comprehensive data set on the developed jointed aquifer within the regionally prominent St. Gallen Fault Zone. The geothermal project has been halted in May 2014. This episode is a data set for correlating seismic activity to fluid injection and gas-water production that lead to increased seismic activity in the past.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=afc834a3-f28b-44a9-ad29-24a4e4c6262d',
#    'id': 'afc834a3-f28b-44a9-ad29-24a4e4c6262d',
#    'status': 0,
#    'title': 'Episode ST. GALLEN: geothermal project - dataset',
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/SG'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=d3d19a14-2f05-4b5f-8ef3-7920a8ad1266&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=d3d19a14-2f05-4b5f-8ef3-7920a8ad1266&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-001',
#    'description': 'The EPISODES Platform integrates research infrastructure of EPOS TCS AH (https://tcs.ah-epos.eu/). It provides access to Episodes, which are collections of time-correlated geophysical, technological and other relevant geodata, relating comprehensively anthropogenic seismicity to its industrial cause.',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=d3d19a14-2f05-4b5f-8ef3-7920a8ad1266',
#    'id': 'd3d19a14-2f05-4b5f-8ef3-7920a8ad1266',
#    'status': 0,
#    'title': 'List of episodes',
#    'uid': 'anthropogenic_hazards/distribution/episodes'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=ea2419eb-08f9-4169-85c8-916d1ce8f882&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.table.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=ea2419eb-08f9-4169-85c8-916d1ce8f882&format=application/epos.table.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-001',
#    'description': 'The EPISODES Platform integrates research infrastructure of EPOS TCS AH (https://tcs.ah-epos.eu/). It provides access to applications, which are software tools to process and analyze the data. They can be used to relate seismicity and technological factors for hazard assessment and other scientific purposes.',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=ea2419eb-08f9-4169-85c8-916d1ce8f882',
#    'id': 'ea2419eb-08f9-4169-85c8-916d1ce8f882',
#    'status': 0,
#    'title': 'List of applications',
#    'uid': 'anthropogenic_hazards/distribution/apps'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=a67088bf-2f40-46a0-8727-b6f6eef782e2&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=a67088bf-2f40-46a0-8727-b6f6eef782e2&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-023',
#    'description': "Enables to list data items contained in the episode (dataset) as ‘Catalog', 'Seismic Network', 'Event related waveforms', 'Velocity model' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. Situated in the North of the Nottinghamshire Coalfield, Thoresby Colliery closed in 2015 and was the last deep coal mine in England's East Midlands. Production at the mine lasted over 90 years with the extraction of Middle Coal Measure seams at depths between 650m to 820m below ground level. Sherwood Sandstone (containing fissures at the surface presumed to be associated with mining) overlie the Middle Coal Measures and form the surface rock in the Thoresby Colliery area. Workings of the colliery extend beneath Thoresby Park near Edwinstowe where over 100 felt tremors were reported by the public between June 1989 and August 1990 and have since been associated with induced seismicity from the longwall mining of coal in the area (Bishop et al., 1993 and Styles et al., 1997 – references in episode repository). This episode contains microseismic monitoring data caused by the underground mining of coal at Thoresby Colliery between late 1996 and early 1997.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=a67088bf-2f40-46a0-8727-b6f6eef782e2',
#    'id': 'a67088bf-2f40-46a0-8727-b6f6eef782e2',
#    'status': 0,
#    'title': 'Episode THORESBY COLLIERY: underground coal mining - dataset',
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/THORESBY_COLLIERY'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=97305fbf-6de4-4d52-b5a7-b2154576c653&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'type': 'ORIGINAL'},
#     {'format': 'application/epos.geo+json',
#      'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=97305fbf-6de4-4d52-b5a7-b2154576c653&format=application/epos.geo+json',
#      'label': 'GEOJSON',
#      'type': 'CONVERTED'}],
#    'ddss': 'WP14-DDSS-027',
#    'description': "Enables to list data items contained in the episode (dataset) as ‘Catalog', 'Seismic Network', 'Event related waveforms', 'Faults' and some 'Industrial data', features filtering. Episode comprehensively describes a geophysical process induced or triggered by human technological activity, which could pose a hazard for populations, infrastructure and environment. In recent years the seismicity rate and magnitude of seismicity in Oklahoma has increased. It has been found that this is due to the injection of fluids for both conventional and unconvential hydrocarbon exploitation as well as waste water injection.",
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=97305fbf-6de4-4d52-b5a7-b2154576c653',
#    'id': '97305fbf-6de4-4d52-b5a7-b2154576c653',
#    'status': 0,
#    'title': 'Episode OKLAHOMA: conventional and unconventional hydrocarbon extraction and wastewater injection - dataset',
#    'uid': 'anthropogenic_hazards/distribution/episode-elements/OK'}]}

# %% [markdown]
# Each one of the *results* object has these properties:
# - "**availableFormats**": an array of elements each representing a file format that can be downloaded for this resource, including the format type, the url to get the resource with that specific format, a label, and type which define if the format is natively available of it needs a conversion.
# - "ddss": a string representing the identifier of the resource.
# - "**description**": a string containing a detailed description of the dataset, including the purpose, content, and objectives.
# - "**href**": a string representing the URL where the EPOS ICS-C API serve the details of the resources.
# - "id": a string representing the unique identifier of this dataset.
# - "status": an integer representing the status of the resource.
# - "**title**": a string representing the title of the resource.
# - "**uid**": a string representing the unique identifier of the resource.

# %% [markdown]
# Here it is an instance of the first resource:

# %%
data['results'][0]
# Out:
# {'availableFormats': [{'format': 'text/plain',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=d5c38c33-7548-4731-998c-572c24622365&format=text/plain',
#    'label': 'TEXT/PLAIN',
#    'type': 'ORIGINAL'}],
#  'ddss': 'WP13-DDSS-002',
#  'description': 'IMAGE consists of 41 magnetometer stations maintained by 8 institutes from Finland, Germany, Norway, Poland, Russia and Sweden. The prime objectives of IMAGE are to study auroral electrojets and moving two-dimensional current systems.',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=d5c38c33-7548-4731-998c-572c24622365',
#  'id': 'd5c38c33-7548-4731-998c-572c24622365',
#  'status': 0,
#  'title': 'Magnetometer data of the International Monitor for Auroral Geomagnetic Effects (IMAGE)',
#  'uid': 'https://www.epos-eu.org/epos-dcat-ap/GeoElectroMagnetism/WP13-DDSS-002/IMAGE/Distribution'}

# %% [markdown]
# ## Details
#
# To retrieve all the detailed information about this resource is enough to do a GET request, using also this time the *requests* library, on the *href* property.

# %%
response_detail = requests.get(data['results'][0]['href'])
data_details = response_detail.json()

# %% [markdown]
# The details response payload have this structure:
# - **availableFormats**: an array that contains multiple object with details about the available format for the data, one for each available format.
# - **dataProvider**: an array that contains objects with details about the data provider of the resource, one resource can have multiple dataprovider and each one of these can have multiple dataproviders related, also, if available is present an url to the page of the dataprovider.
# - **description**: a string that describes the purpose and objectives of the resource.
# - **downloadURL**: This property contains a URL that is a direct link to a downloadable file in a given format. An empty string indicating that there is no download URL available.
# - **endpoint**: a string that provides the URL endpoint for accessing the data.
# - **frequencyUpdate**: a string that indicates the frequency or the strategy of updates to the data.
# - **hasQualityAnnotation**: a string that provides a link to information about the quality assurance of the data.
# - **href**: a string that provides a link to the details of the resource.
# - **id**: a string that serves as a unique identifier for the resource.
# - **internalID**: an array that contains the internal identifier for the resource.
# - **keywords**: an array of strings that contain keywords related to the data.
# - **license**: a string that provides a link to the license agreement for accessing the data.
# - **operationid**: a string that provides a link to the operation of the resource, it contains the unique identifier of the operation.
# - **scienceDomain**: an array that provides the science domain of the resource.
# - **serviceDescription**: a string that describes the purpose of the web service.
# - **serviceDocumentation**: a string that provides a link to the documentation for the web service.
# - **serviceEndpoint**: a string that provides the URL endpoint for accessing the web service.
# - **serviceName**: a string that provides the name of the web service.
# - **serviceParameters**: an array that contains an object with details about the parameters required to use the web service (in this case, the parameter "start" is required and has a default value of "19821001").
# - **serviceProvider**: an object with details about the service provider of the resource, one resource can have one service provider and each one of these can have multiple service providers related, also, if available is present an url to the page of the serviceprovider.
# - **serviceSpatial**: an object that contains spatial information about the service like a path of coordinates.
# - **serviceTemporalCoverage**: an object that provides temporal coverage information for the service.
# - **serviceType**: an array that provides the type of the service.
# - **spatial**: an object that contains spatial information about the resource like a path defined by a set of coordinates.
# - **temporalCoverage**: an object that provides temporal coverage information for the resource.
# - **title**: a string that provides the title of the resource.
# - **type**: a string that provides the type of the resource.
# - **uid**: a string that serves as a unique identifier of the resource.

# %%
data_details
# Out:
# {'availableFormats': [{'format': 'text/plain',
#    'href': 'https://www.ics-c.epos-eu.org/api/v1/execute?id=d5c38c33-7548-4731-998c-572c24622365&format=text/plain',
#    'label': 'TEXT/PLAIN',
#    'type': 'ORIGINAL'}],
#  'dataProvider': [{'MainDataProvider': 'Finnish Meteorological Institute'}],
#  'description': 'IMAGE consists of 41 magnetometer stations maintained by 8 institutes from Finland, Germany, Norway, Poland, Russia and Sweden. The prime objectives of IMAGE are to study auroral electrojets and moving two-dimensional current systems.',
#  'downloadURL': '',
#  'endpoint': 'https://space.fmi.fi/image/epos/data_download_epos.php?starttime={start}',
#  'frequencyUpdate': 'http://purl.org/cld/freq/continuous',
#  'hasQualityAnnotation': 'https://space.fmi.fi/image/www_old/accuracy.html',
#  'href': 'https://www.ics-c.epos-eu.org/api/v1/resources/details?id=d5c38c33-7548-4731-998c-572c24622365',
#  'id': 'd5c38c33-7548-4731-998c-572c24622365',
#  'internalID': ['WP13-DDSS-002'],
#  'keywords': ['magnetic field',
#   'geomagnetism',
#   'auroral electrojet',
#   'magnetism',
#   'variometer',
#   'space weather',
#   'substorm'],
#  'license': 'http://space.fmi.fi/image/www/index.php?page=rules_of_road',
#  'operationid': 'https://www.epos-eu.org/epos-dcat-ap/GeoElectroMagnetism/WP13-DDSS-002/IMAGE/Operation',
#  'scienceDomain': ['epos:Magneticfield'],
#  'serviceDescription': 'The IMAGE web service makes available data from the IMAGE magnetometer network in text format. The output data files contain a full day (24 hours) of data with the original sampling rate (10 s or 20s).',
#  'serviceDocumentation': 'https://space.fmi.fi/image/epos/image-epos.html',
#  'serviceEndpoint': 'https://space.fmi.fi/image/epos/data_download_epos.php?starttime=',
#  'serviceName': 'Web service for International Monitor for Auroral Geomagnetic Effects (IMAGE) data',
#  'serviceParameters': [{'defaultValue': '19821001',
#    'label': 'Date (yyyymmdd)',
#    'maxValue': '21000101',
#    'minValue': '19821001',
#    'name': 'start',
#    'required': True,
#    'type': 'date',
#    'valuePattern': 'YYYYMMDD'}],
#  'serviceProvider': 'Finnish Meteorological Institute',
#  'serviceSpatial': {'paths': [[[40.0, 50.0],
#     [0.0, 50.0],
#     [0.0, 80.0],
#     [40.0, 80.0],
#     [40.0, 50.0]]],
#   'wkid': 4326},
#  'serviceTemporalCoverage': {'startDate': '1982-10-01T00:00:00Z'},
#  'serviceType': ['epos:Magneticfield'],
#  'spatial': {'paths': [[[40.0, 50.0],
#     [0.0, 50.0],
#     [0.0, 80.0],
#     [40.0, 80.0],
#     [40.0, 50.0]]],
#   'wkid': 4326},
#  'temporalCoverage': {'startDate': '1982-10-01T00:00:00Z'},
#  'title': 'Magnetometer data of the International Monitor for Auroral Geomagnetic Effects (IMAGE)',
#  'type': 'WEB_SERVICE',
#  'uid': 'https://www.epos-eu.org/epos-dcat-ap/GeoElectroMagnetism/WP13-DDSS-002/IMAGE/Distribution'}

# %% [markdown]
# ## Download original data
#
# To download the original data of one of the resource is enough to use the *requests* to execute a GET request using the id of  the resource and on the original URL endpoint

# %%
response_original_url = requests.get('https://www.ics-c.epos-eu.org/api/v1/getoriginalurl?id=' + data_details['id'])
data_original_url = response_original_url.json()

# %% [markdown]
# The response is a Json Object with only one property: *url*.
# The url is where the resource is located.

# %%
data_original_url
# Out:
# {'url': 'https://space.fmi.fi/image/epos/data_download_epos.php?starttime=19821001'}

# %% [markdown]
# Using *requests* is possible to get the information located at that URL

# %%
response_original_data = requests.get(data_original_url['url'])
original_data = response_original_data.content
original_data
# Out:
# b'YYYY MM DD HH MM SS     MUO X   MUO Y   MUO Z   PEL X   PEL Y   PEL Z \n   0  0  0  0  0  0      68.03   23.56     0     66.80   24.27     0  \n----------------------------------------------------------------------\n1982 10 01 00 00 00    11452.4   825.6 51309.0 12020.5   796.1 50635.3\n1982 10 01 00 00 20    11450.4   827.6 51308.1 12019.5   797.1 50635.3\n1982 10 01 00 00 40    11447.5   826.6 51309.0 12017.5   797.1 50634.4\n1982 10 01 00 01 00    11447.5   825.6 51310.0 12017.5   796.1 50634.4\n1982 10 01 00 01 20    11449.4   824.6 51310.0 12019.5   797.1 50634.4\n1982 10 01 00 01 40    11451.4   825.6 51309.0 12020.5   798.1 50634.4\n1982 10 01 00 02 00    11451.4   828.5 51307.1 12021.5   800.1 50633.4\n1982 10 01 00 02 20    11449.5   828.5 51307.1 12020.5   799.1 50633.4\n1982 10 01 00 02 40    11448.5   829.5 51306.2 12019.5   800.1 50632.4\n1982 10 01 00 03 00    11447.5   830.5 51306.2 12018.5   801.1 50631.5\n1982 10 01 00 03 20    11447.5   833.5 51305.2 12019.5   803.1 50630.5\n1982 10 01 00 03 40    11446.6   833.5 51306.1 12019.5   802.1 50630.5\n1982 10 01 00 04 00    11445.6   833.5 51306.1 12020.5   801.1 50629.5\n1982 10 01 00 04 20    11446.6   832.5 51305.2 12022.4   801.1 50629.5\n1982 10 01 00 04 40    11449.5   831.5 51304.2 12024.4   800.1 50628.5\n1982 10 01 00 05 00    11451.4   829.5 51303.3 12026.4   799.1 50629.5\n1982 10 01 00 05 20    11451.4   829.5 51298.5 12027.4   799.1 50629.5\n1982 10 01 00 05 40    11450.5   831.5 51294.7 12027.4   800.1 50627.6\n1982 10 01 00 06 00    11448.5   832.5 51292.8 12025.4   800.1 50627.6\n1982 10 01 00 06 20    11447.5   833.5 51292.8 12024.4   802.1 50626.6\n1982 10 01 00 06 40    11447.5   831.5 51292.8 12024.4   801.1 50625.6\n1982 10 01 00 07 00    11450.5   831.5 51292.8 12026.4   801.1 50624.6\n1982 10 01 00 07 20    11455.3   829.5 51292.8 12029.3   801.1 50624.6\n1982 10 01 00 07 40    11457.3   827.5 51294.7 12031.3   799.1 50625.6\n1982 10 01 00 08 00    11459.2   825.6 51292.8 12032.3   798.1 50625.6\n1982 10 01 00 08 20    11458.2   824.6 51292.8 12032.3   797.1 50624.6\n1982 10 01 00 08 40    11463.1   824.6 51292.8 12035.2   798.1 50624.6\n1982 10 01 00 09 00    11468.0   822.6 51291.9 12039.2   795.1 50624.6\n1982 10 01 00 09 20    11469.9   821.6 51290.9 12040.2   794.2 50625.6\n1982 10 01 00 09 40    11470.9   820.6 51288.1 12040.2   793.2 50625.6\n1982 10 01 00 10 00    11469.9   819.7 51287.1 12039.2   792.2 50624.6\n1982 10 01 00 10 20    11469.9   821.6 51286.1 12038.2   794.2 50624.6\n1982 10 01 00 10 40    11466.0   823.6 51285.2 12036.2   793.2 50623.7\n1982 10 01 00 11 00    11463.1   824.6 51284.2 12035.2   795.1 50622.7\n1982 10 01 00 11 20    11460.2   825.6 51286.1 12033.3   794.2 50621.7\n1982 10 01 00 11 40    11461.2   825.6 51283.2 12033.3   794.2 50620.7\n1982 10 01 00 12 00    11459.2   824.6 51286.1 12032.3   793.2 50620.7\n1982 10 01 00 12 20    11456.3   825.6 51286.1 12031.3   793.2 50619.8\n1982 10 01 00 12 40    11453.3   824.6 51287.1 12028.3   791.2 50618.8\n1982 10 01 00 13 00    11454.3   822.7 51287.1 12027.3   790.2 50618.8\n1982 10 01 00 13 20    11454.3   821.7 51287.1 12029.3   789.2 50617.8\n1982 10 01 00 13 40    11453.3   821.7 51288.0 12029.3   788.2 50617.8\n1982 10 01 00 14 00    11452.4   824.6 51288.0 12028.3   789.2 50617.8\n1982 10 01 00 14 20    11448.4   821.7 51286.1 12024.4   787.3 50616.8\n1982 10 01 00 14 40    11446.5   822.7 51285.1 12024.4   788.3 50614.9\n1982 10 01 00 15 00    11445.5   821.7 51285.1 12024.4   787.3 50614.9\n1982 10 01 00 15 20    11446.5   821.7 51285.1 12026.4   789.2 50614.9\n1982 10 01 00 15 40    11445.5   822.7 51287.0 12026.4   787.3 50614.9\n1982 10 01 00 16 00    11441.6   822.7 51287.0 12025.4   788.3 50614.9\n1982 10 01 00 16 20    11438.7   823.7 51288.0 12023.4   789.2 50614.9\n1982 10 01 00 16 40    11438.7   823.7 51289.9 12022.4   789.2 50615.9\n1982 10 01 00 17 00    11438.7   823.7 51289.9 12022.4   789.2 50615.9\n1982 10 01 00 17 20    11440.7   824.7 ...
