# %% [markdown]
# # Hand On the ENVRI Catalogue API

# %% [markdown]
# ## Search
# The search function of the ENVRI Catalogue API allows users to query the database of metadata contained into the ENVRI Catalogue. The API uses a RESTful architecture, which means that users can send HTTP requests to the API endpoints and receive responses in JSON.
#
# *import requests* is a Python statement that imports the *requests* library, which is a popular Python library for making HTTP requests. The *requests* library provides an interface for sending HTTP requests and handling their responses, making it a popular good choice for RESTfull API access.

# %%
import requests

# %% [markdown]
# *api_url* is assigned to 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1'. This represents the base URL for the EPOS ICS-C API.

# %%
api_url = 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1'

# %% [markdown]
# the *requests* library to send an HTTP GET request to the ENVRI Catalogue API search endpoint, and then extract the JSON data from the response.
# The parameters in the query:
# - *facets* is set to false, this parameter is set to true when the client want the API to return the information in a categorized structure, for example the EPOS Data Portal show the information as in different category on multiple levels.
# - *q* is the search by free text, it narrows down the results based on which resource contains in the title or in the description or as keyword the specific string

# %%
search_endpoint = api_url + '/resources/search?q=&facets=false'

response_search = requests.get(search_endpoint)
data = response_search.json()

# %% [markdown]
# This is a JSON object with two key:
#
# 1. "*filters*" which has an array of four objects as its value: "*keyword*", "*organisations*", "*sciencedomains*" and "*servicetype*". Each object represents a filter category and has two key-value pairs:
#     - "*name*": a string that represents the name of the filter category.
#     - "*children*": an array of objects that represent the subcategories for the filter category. Each subcategory object has two key-value pairs:
#         - "*id*": a string that represents a unique identifier for the subcategory.
#         - "*name*": a string that represents the name of the subcategory.
# 2. "results*" that holds an array of object representing all the resources available in the system.

# %%
data
# Out:
# {'filters': [{'children': [{'id': 'YWN0cmlz', 'name': 'actris'},
#     {'id': 'YWVyaWFsIGltYWdpbmc=', 'name': 'aerial imaging'},
#     {'id': 'YWVyb3NvbA==', 'name': 'aerosol'},
#     {'id': 'YWVyb3NvbHM=', 'name': 'aerosols'},
#     {'id': 'YWlyYm9ybmU=', 'name': 'airborne'},
#     {'id': 'YWxnYWU=', 'name': 'algae'},
#     {'id': 'YXJnbw==', 'name': 'argo'},
#     {'id': 'YXRtb3NwaGVyZQ==', 'name': 'atmosphere'},
#     {'id': 'YmVudGhvcw==', 'name': 'benthos'},
#     {'id': 'YmlvZGl2ZXJzaXR5', 'name': 'biodiversity'},
#     {'id': 'YmlvbG9neQ==', 'name': 'biology'},
#     {'id': 'Y2xvdWRz', 'name': 'clouds'},
#     {'id': 'ZGF0YQ==', 'name': 'data'},
#     {'id': 'ZWN2', 'name': 'ecv'},
#     {'id': 'ZXBpYmVudGhvcw==', 'name': 'epibenthos'},
#     {'id': 'ZmFpcg==', 'name': 'fair'},
#     {'id': 'ZmxvYXQ=', 'name': 'float'},
#     {'id': 'Z2VvbG9neQ==', 'name': 'geology'},
#     {'id': 'Z2xvYmFsIG9jZWFuIG9ic2VydmluZyBsZXZlbA==',
#      'name': 'global ocean observing level'},
#     {'id': 'Z2xvYmFsLW9jZWFu', 'name': 'global-ocean'},
#     {'id': 'aGlzdG9yaWNhbCByZWNvcmRz', 'name': 'historical records'},
#      'name': 'stypes:EOSCresource'},
#     {'id': '09fc1bce-bc26-4293-9cd7-e185744b31b0',
#      'name': 'stypes:SemAssetService'},
#     {'id': '45e33888-ebcd-4c59-b35d-86b8485bbccd',
#      'name': 'stypes:CatalogueService'},
#     {'id': 'd701a875-7b40-4933-87b0-9179a370d742',
#      'name': 'stypes:MetadataService'},
#     {'id': 'e15b959f-647e-465a-a521-29070cd2854f',
#      'name': 'stypes:DataService'}],
#    'name': 'servicetypes'}],
#  'results': [{'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=7d5bc4cc-d353-4542-8890-3d8abc833033&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Map of the flattened phase difference (full evolution) computed between two SAR images acquired over the same scene with the same geometry',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=7d5bc4cc-d353-4542-8890-3d8abc833033',
#    'id': '7d5bc4cc-d353-4542-8890-3d8abc833033',
#    'status': 1,
#    'title': 'Unwrapped Interferograms',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Unwrapped_Interferogram/Distribution/Unwrap_Interf'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=bbd61629-34dd-45dd-aeb7-c39b7f368017&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'This call to the EcoPortal API retrieves metadata for all resources published in EcoPortal.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=bbd61629-34dd-45dd-aeb7-c39b7f368017',
#    'id': 'bbd61629-34dd-45dd-aeb7-c39b7f368017',
#    'status': 0,
#    'title': 'EcoPortal Metadata',
#    'uid': 'https://data.ecoportal.lifewatch.eu/ontologies-full'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=f71b6ad0-0341-4f00-8214-d4773acebaa9&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Atmospheric Phase Screen computed from Global Atmospheric Model for singel interferograms',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=f71b6ad0-0341-4f00-8214-d4773acebaa9',
#    'id': 'f71b6ad0-0341-4f00-8214-d4773acebaa9',
#    'status': 1,
#    'title': 'Interferogram Atmospheric Phase Screen from Global Atmospheric Model',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Interferogram_APS_Global_Model/Distribution/APS_model'},
#   {'availableFormats': [{'format': 'application/rdf+xml',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=a80bbab0-02b1-436d-a141-a5d1489e9372&format=application/rdf+xml',
#      'label': 'APPLICATION/RDF+XML',
#      'originalFormat': 'application/rdf+xml',
#      'type': 'ORIGINAL'}],
#    'description': 'Web Service endpoint to query the LifeWatch ERIC Metadata Catalogue',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=a80bbab0-02b1-436d-a141-a5d1489e9372',
#    'id': 'a80bbab0-02b1-436d-a141-a5d1489e9372',
#    'status': 0,
#    'title': 'LifeWatch ERIC Metadata Catalogue Web Service',
#    'uid': 'https://metadatacatalogue.lifewatch.eu/doc/api'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=dea605b1-eb4e-41b2-8e0b-79c4b4447db7&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'API documentation for the ACTRIS metadata catalog. In order to add or delete metadata in the catalog, you would need to be a registered data provider and create an API token. Please contact the ACTRIS Data Centre (DVAS unit) if you have any questions or need an API token.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=dea605b1-eb4e-41b2-8e0b-79c4b4447db7',
#    'id': 'dea605b1-eb4e-41b2-8e0b-79c4b4447db7',
#    'status': 0,
#    'title': 'ACTRIS metadata catalog REST API',
#    'uid': 'https://prod-actris-md.nilu.no/Distribution/5e91c124-ac29-4be3-a700-1fc44bb636b4'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=f1642ec7-312b-45f3-9f46-33f61e575bb5&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'API documentation for the ACTRIS metadata catalog. In order to add or delete metadata in the catalog, you would need to be a registered data provider and create an API token. Please contact the ACTRIS Data Centre (DVAS unit) if you have any questions or need an API token.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=f1642ec7-312b-45f3-9f46-33f61e575bb5',
#    'id': 'f1642ec7-312b-45f3-9f46-33f61e575bb5',
#    'status': 0,
#    'title': 'ACTRIS metadata catalog REST API',
#    'uid': 'https://prod-actris-md.nilu.no/Distribution'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=76ebf55a-5ffb-4771-abda-4eb80e613dc6&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'API documentation for the ACTRIS metadata catalog. In order to add or delete metadata in the catalog, you would need to be a registered data provider and create an API token. Please contact the ACTRIS Data Centre (DVAS unit) if you have any questions or need an API token.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=76ebf55a-5ffb-4771-abda-4eb80e613dc6',
#    'id': '76ebf55a-5ffb-4771-abda-4eb80e613dc6',
#    'status': 0,
#    'title': 'ACTRIS metadata catalog REST API',
#    'uid': 'https://prod-actris-md.nilu.no/Distribution/76e598f2-3890-4794-ab7d-c9754ded35c8'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=8819aa1d-c4a3-47ae-b84a-5da2ec5b4274&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'API documentation for the ACTRIS metadata catalog. In order to add or delete metadata in the catalog, you would need to be a registered data provider and create an API token. Please contact the ACTRIS Data Centre (DVAS unit) if you have any questions or need an API token.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=8819aa1d-c4a3-47ae-b84a-5da2ec5b4274',
#    'id': '8819aa1d-c4a3-47ae-b84a-5da2ec5b4274',
#    'status': 0,
#    'title': 'ACTRIS metadata catalog REST API',
#    'uid': 'https://prod-actris-md.nilu.no/Distribution/9ae872d5-3c42-4f01-83c5-ec7a883eb638'},
#   {'availableFormats': [{'format': 'application/http',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=5362141e-9b21-4aa6-9159-d228ee8024c6&format=application/http',
#      'label': 'APPLICATION/HTTP',
#      'originalFormat': 'application/http',
#      'type': 'ORIGINAL'}],
#    'description': 'This server documents the vocabulary and controlled lists of terms used by the Aerosol, Clouds and Trace Gases Research Infrastructure (ACTRIS).',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=5362141e-9b21-4aa6-9159-d228ee8024c6',
#    'id': '5362141e-9b21-4aa6-9159-d228ee8024c6',
#    'status': 0,
#    'title': 'ACTRIS Vocabulary Server',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/07d07705-4991-4842-8dc4-4bb4c8ac52a9'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=f05bd9a7-090d-4621-804a-d3dcf0650875&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Lookup table to convert radar coordinates in ground coordinates',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=f05bd9a7-090d-4621-804a-d3dcf0650875',
#    'id': 'f05bd9a7-090d-4621-804a-d3dcf0650875',
#    'status': 1,
#    'title': 'Lookup table from radar coordinates to ground coordinates',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Lookup_Table_Radar2Ground_Coordinates/Distribution/LUT_radar2ground'},
#   {'description': 'The Ifremer OpenSearch service is designed to facilitate high-performance geospatial data discovery and access with the ability to support multi-metadata standard specifications. The service is powered by Big Data technologies. This is a joint effort between Ifremer CERSAT, and IT Department.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=c0203678-1905-4662-b6b3-2c1c69ff6103',
#    'id': 'c0203678-1905-4662-b6b3-2c1c69ff6103',
#    'status': 0,
#    'title': 'Ifremer OpenSearch service',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/13aa08c0-e38f-4e62-963c-9d503434d0b8'},
#   {'description': 'The Argo data accessible through a Swagger API',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=b9ce3a56-4d58-431b-a9c2-b600bd2deca6',
#    'id': 'b9ce3a56-4d58-431b-a9c2-b600bd2deca6',
#    'status': 0,
#    'title': 'Argo Data subsetting API',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/4764d1e3-60aa-4896-aa8c-2dcda1d8dcb8'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=e0db7f9d-60ba-40a9-a808-b3895f424265&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Argo SPARQL Endpoint containing floats metadata such as vertical profiles, sensors, deployment and provenance.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=e0db7f9d-60ba-40a9-a808-b3895f424265',
#    'id': 'e0db7f9d-60ba-40a9-a808-b3895f424265',
#    'status': 0,
#    'title': 'Argo SPARQL Endpoint',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/358180a0-7cf9-46f5-9492-f678b750cee2'},
#   {'description': 'The Argo metadata accessible through a Swagger API',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=5f488b71-17a5-4601-a851-70f1cafaef3c',
#    'id': '5f488b71-17a5-4601-a851-70f1cafaef3c',
#    'status': 0,
#    'title': 'Argo Metadata API',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/2936412d-a6a3-465d-a44a-f867543396c3'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=d33fcbc5-85b0-4f9a-b766-b1fda67a3938&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'ERDDAP is a data server that gives you a simple, consistent way to download subsets of scientific datasets in common file formats and make graphs and maps. This particular ERDDAP installation has oceanographic data (for example, data from satellites and buoys).',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=d33fcbc5-85b0-4f9a-b766-b1fda67a3938',
#    'id': 'd33fcbc5-85b0-4f9a-b766-b1fda67a3938',
#    'status': 0,
#    'title': 'Ifremer ERDAPP server',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/f58d9e00-bd3b-4254-96a9-577913931639'},
#   {'description': 'The NERC Vocabulary Server contains Argo vocabularies. Originally known as reference tables, they are used extensively to constrain the contents of the Argo NetCDF files, and to enhance the interoperability of the Argo data system. The transfer of existing reference tables to NVS collections, as well as the creation of new ones, is an ongoing effort managed by the Argo Vocabulary Task Team and supported by BODC.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=77134de9-0111-4347-8d67-60a1eb827f9c',
#    'id': '77134de9-0111-4347-8d67-60a1eb827f9c',
#    'status': 0,
#    'title': 'The NERC Vocabulary Server',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/f58d9e00-bd3b-4254-96a9-577913931640'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=640b7083-cec2-499d-86f6-7a6f85ad9bf8&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Map of the spatial coherence computed between two SAR images acquired over the same scene with the same geometry',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=640b7083-cec2-499d-86f6-7a6f85ad9bf8',
#    'id': '640b7083-cec2-499d-86f6-7a6f85ad9bf8',
#    'status': 1,
#    'title': 'Spatial Coherence',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Spatial_Coherence/Distribution/Spac_Coh'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=4c34373a-935a-4b00-9225-469b99be95bf&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Digital Elevation Model provided in radar coordinates',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=4c34373a-935a-4b00-9225-469b99be95bf',
#    'id': '4c34373a-935a-4b00-9225-469b99be95bf',
#    'status': 1,
#    'title': 'DEM in radar geometry',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/DEM_Radar_Geometry/Distribution/DEM_radar'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=6d8ba917-c041-4f85-b866-9391e3ac119d&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Temporal evoluton of the surface displacement projected along the satellite Line of Sight (LOS)',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=6d8ba917-c041-4f85-b866-9391e3ac119d',
#    'id': '6d8ba917-c041-4f85-b866-9391e3ac119d',
#    'status': 1,
#    'title': 'LOS Displacement Time Series',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/LOS_Displacement_Time_Series/Distribution/LOS_Displ_TS'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=a3a7e9a4-0e66-4b0b-869a-281b86106b14&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Map of the unit vectors of the satellite Line of Sight',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=a3a7e9a4-0e66-4b0b-869a-281b86106b14',
#    'id': 'a3a7e9a4-0e66-4b0b-869a-281b86106b14',
#    'status': 1,
#    'title': 'Map of LOS Vector',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Map_of_LOS_Vector/Distribution/LOS_Vect'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=d05569de-3b97-4396-91be-650916fc07c3&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Map of the flattened phase difference (restricted in the -pi,pi domain) computed between two SAR images acquired over the same scene with the same geometry',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=d05569de-3b97-4396-91be-650916fc07c3',
#    'id': 'd05569de-3b97-4396-91be-650916fc07c3',
#    'status': 1,
#    'title': 'Wrapped Interferograms',
#    'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Wrapped_Interferogram/Distribution/Wrap_Interf'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=c6fef9f8-641d-4468-9229-1b5aadaf510c&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'The World Register of Marine Species (WoRMS) is a species information backbone, providing an authoritative classification and catalogue of names of marine organisms. WoRMS contains the names, synonyms, and vernacular names, as well as references, images, biogeographic data, distributions, and traits, where those information are available. The information in WoRMS is curated and maintained at VLIZ, and a number of services to query for information in WoRMS are provided via its website (https://www.marinespecies.org/). The data system behind WoRMS is called Aphia. All the names in WoRMS are tagged with an unique and persistent ID: the AphiaID. Using the WoRMS RESTful services, one can obtain the information held in Aphia using the AphiaID as key, or using the names, external identifiers, classification and trait keywords, etc. The service AphiaIDsByAttributeKeyID is a query to get a list of AphiaIDs (max 50) with attribute tree for a given attribute ID.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=c6fef9f8-641d-4468-9229-1b5aadaf510c',
#    'id': 'c6fef9f8-641d-4468-9229-1b5aadaf510c',
#    'status': 0,
#    'title': 'AphiaIDsByAttributeKeyID',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distIdByAttrKeyId'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=b283a4db-d359-41fa-9281-d13f93d40148&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'The World Register of Marine Species (WoRMS) is a species information backbone, providing an authoritative classification and catalogue of names of marine organisms. WoRMS contains the names, synonyms, and vernacular names, as well as references, images, biogeographic data, distributions, and traits, where those information are available. The information in WoRMS is curated and maintained at VLIZ, and a number of services to query for information in WoRMS are provided via its website (https://www.marinespecies.org/). The data system behind WoRMS is called Aphia. All the names in WoRMS are tagged with an unique and persistent ID: the AphiaID. Using the WoRMS RESTful services, one can obtain the information held in Aphia using the AphiaID as key, or using the names, external identifiers, classification and trait keywords, etc. The service AphiaAttributeValuesByCategoryID is a query to get the list values that are grouped by categoryID.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=b283a4db-d359-41fa-9281-d13f93d40148',
#    'id': 'b283a4db-d359-41fa-9281-d13f93d40148',
#    'status': 0,
#    'title': 'AphiaAttributeValuesByCategoryID',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distAttrValuesByCatId'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=68016eac-f227-4833-87dd-347c18265711&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'The World Register of Marine Species (WoRMS) is a species information backbone, providing an authoritative classification and catalogue of names of marine organisms. WoRMS contains the names, synonyms, and vernacular names, as well as references, images, biogeographic data, distributions, and traits, where those information are available. The information in WoRMS is curated and maintained at VLIZ, and a number of services to query for information in WoRMS are provided via its website (https://www.marinespecies.org/). The data system behind WoRMS is called Aphia. All the names in WoRMS are tagged with an unique and persistent ID: the AphiaID. Using the WoRMS RESTful services, one can obtain the information held in Aphia using the AphiaID as key, or using the names, external identifiers, classification and trait keywords, etc. The service AphiaTaxonRanksByID is a query to get the taxonomic ranks by their identifier.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=68016eac-f227-4833-87dd-347c18265711',
#    'id': '68016eac-f227-4833-87dd-347c18265711',
#    'status': 0,
#    'title': 'AphiaTaxonRanksByID',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distTaxRankById'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=331a3954-429a-4fc0-a6d1-660b42dfe888&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
# ...
#    'status': 0,
#    'title': 'AphiaRecordsByNames',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distRecByNames'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=e74a39c0-bcc1-4c4b-81c9-d408dc1016e1&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'The World Register of Marine Species (WoRMS) is a species information backbone, providing an authoritative classification and catalogue of names of marine organisms. WoRMS contains the names, synonyms, and vernacular names, as well as references, images, biogeographic data, distributions, and traits, where those information are available. The information in WoRMS is curated and maintained at VLIZ, and a number of services to query for information in WoRMS are provided via its website (https://www.marinespecies.org/). The data system behind WoRMS is called Aphia. All the names in WoRMS are tagged with an unique and persistent ID: the AphiaID. Using the WoRMS RESTful services, one can obtain the information held in Aphia using the AphiaID as key, or using the names, external identifiers, classification and trait keywords, etc. The service AphiaTaxonRanksByName is a query to get the taxonomic ranks by their name. ',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=e74a39c0-bcc1-4c4b-81c9-d408dc1016e1',
#    'id': 'e74a39c0-bcc1-4c4b-81c9-d408dc1016e1',
#    'status': 0,
#    'title': 'AphiaTaxonRanksByName',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distTaxRankByName'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=ff4a5ed4-f5e6-454b-a133-e54e5c1d5615&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'The World Register of Marine Species (WoRMS) is a species information backbone, providing an authoritative classification and catalogue of names of marine organisms. WoRMS contains the names, synonyms, and vernacular names, as well as references, images, biogeographic data, distributions, and traits, where those information are available. The information in WoRMS is curated and maintained at VLIZ, and a number of services to query for information in WoRMS are provided via its website (https://www.marinespecies.org/). The data system behind WoRMS is called Aphia. All the names in WoRMS are tagged with an unique and persistent ID: the AphiaID. Using the WoRMS RESTful services, one can obtain the information held in Aphia using the AphiaID as key, or using the names, external identifiers, classification and trait keywords, etc. The service AphiaRecordsByAphiaIDs is a query to get Aphia records for multiple AphiaIDs (max 50).',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=ff4a5ed4-f5e6-454b-a133-e54e5c1d5615',
#    'id': 'ff4a5ed4-f5e6-454b-a133-e54e5c1d5615',
#    'status': 0,
#    'title': 'AphiaRecordsByAphiaIDs',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distRecByAphiaIds'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=9059333f-c585-4d55-816f-cfc0ff2135a6&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'The World Register of Marine Species (WoRMS) is a species information backbone, providing an authoritative classification and catalogue of names of marine organisms. WoRMS contains the names, synonyms, and vernacular names, as well as references, images, biogeographic data, distributions, and traits, where those information are available. The information in WoRMS is curated and maintained at VLIZ, and a number of services to query for information in WoRMS are provided via its website (https://www.marinespecies.org/). The data system behind WoRMS is called Aphia. All the names in WoRMS are tagged with an unique and persistent ID: the AphiaID. Using the WoRMS RESTful services, one can obtain the information held in Aphia using the AphiaID as key, or using the names, external identifiers, classification and trait keywords, etc. The service AphiaAttributesByAphiaID is a query to get a list of attributes for a given AphiaID.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=9059333f-c585-4d55-816f-cfc0ff2135a6',
#    'id': '9059333f-c585-4d55-816f-cfc0ff2135a6',
#    'status': 0,
#    'title': 'AphiaAttributesByAphiaID',
#    'uid': 'https://doi.org/10.14284/wormswebservice_distAttrByAphiaId'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=4fdc26f1-d409-4f27-aef6-36a440f2c330&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Access to waveform quality and availability metrics (JSON format) distributed by the ORFEUS Data Center at KNMI.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=4fdc26f1-d409-4f27-aef6-36a440f2c330',
#    'id': '4fdc26f1-d409-4f27-aef6-36a440f2c330',
#    'status': 1,
#    'title': 'Waveform quality and availability metrics distributed by the ORFEUS Data Center at KNMI',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Seismology/Dataset/003/Distribution/003/ODC'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=b94b2689-f336-4906-8ae4-22a178689095&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'Browsing the product catalogue allows users to search for one or more available products as well as the related data collections. Users can also retrieve the full set of metadata, originators and distributors. The catalogue is integrated with the Map viewer, is compliant with ISO19139 metadata standards and fulfils INSPIRE Directive requirements.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=b94b2689-f336-4906-8ae4-22a178689095',
#    'id': 'b94b2689-f336-4906-8ae4-22a178689095',
#    'status': 0,
#    'title': 'Seadatanet - visualization services (Erddap)',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Dataset/aefb2173-b17b-4955-9c15-6ea175038e45'},
#   {'availableFormats': [{'format': 'application/xml',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=3cab21c3-4c74-474c-8d12-a5c344aa4d8f&format=application/xml',
#      'label': 'APPLICATION/XML',
#      'originalFormat': 'application/xml',
#      'type': 'ORIGINAL'}],
#    'description': 'Browsing the product catalogue allows users to search for one or more available products as well as the related data collections. Users can also retrieve the full set of metadata, originators and distributors. The catalogue is integrated with the Map viewer, is compliant with ISO19139 metadata standards and fulfils INSPIRE Directive requirements.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=3cab21c3-4c74-474c-8d12-a5c344aa4d8f',
#    'id': '3cab21c3-4c74-474c-8d12-a5c344aa4d8f',
#    'status': 0,
#    'title': 'Seadatacloud - Products Catalogue (CSW)',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Dataset/5ffd8aab-a348-4144-9871-f0b33f953ec2'},
#   {'description': 'Contains metadata about Sextant-Seadtanet catalogue products, such as their DCAT description, download link and CDI used.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=d49baa46-f263-4873-9dcc-4c9fcf992daf',
#    'id': 'd49baa46-f263-4873-9dcc-4c9fcf992daf',
#    'status': 0,
#    'title': 'Seadatanet - Sextant SPARQL Endpoint',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/358180a0-7cf9-46f5-9492-f678b750cee1'},
#   {'availableFormats': [{'format': 'application/vnd.fdsn.mseed',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=fb3572d8-a48c-4287-850e-780d1dd51c6b&format=application/vnd.fdsn.mseed',
#      'label': 'APPLICATION/VND.FDSN.MSEED',
#      'originalFormat': 'application/vnd.fdsn.mseed',
#      'type': 'ORIGINAL'}],
#    'description': 'Access to seismic waveforms (miniSEED format) distributed by the ORFEUS Data Center at KNMI.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=fb3572d8-a48c-4287-850e-780d1dd51c6b',
#    'id': 'fb3572d8-a48c-4287-850e-780d1dd51c6b',
#    'status': 1,
#    'title': 'Seismic waveforms distributed by the ORFEUS Data Center at KNMI',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Seismology/Dataset/001/Distribution/001/ODC'},
#   {'description': 'The SIOS observation facility catalogue has been developed to provide an overview of the observation facilities which collect SIOS data. An observation facility can be one instrument or a collection of instruments, e.g. a weather station, and is a term used by the World Meteorological Organization (WMO). The annotation is standardised following the WMO standards as far as possible, in order to make entries unambiguous and interoperable internationally.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=620f1dbd-9486-46b5-81b3-4c473c7d36cc',
#    'id': '620f1dbd-9486-46b5-81b3-4c473c7d36cc',
#    'status': 0,
#    'title': 'SIOS observation facility catalogue - REST API',
#    'uid': 'SIOSOFEndpoint'},
#   {'availableFormats': [{'format': 'application/xml',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=4357588b-0249-4946-b8b8-5ee6adc3c974&format=application/xml',
#      'label': 'APPLICATION/XML',
#      'originalFormat': 'application/xml',
#      'type': 'ORIGINAL'}],
#    'description': 'Access to seismic station metadata (XML and GEOJSON formats) distributed by the ORFEUS Data Center at KNMI.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=4357588b-0249-4946-b8b8-5ee6adc3c974',
#    'id': '4357588b-0249-4946-b8b8-5ee6adc3c974',
#    'status': 1,
#    'title': 'Station metadata distributed by the ORFEUS Data Center at KNMI',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Seismology/Dataset/002/Distribution/002/ODC'},
#   {'description': 'The SIOS CSW catalogue is a machine interface for accessing the metadata records exposed in the SIOS Data access portal. It integrates information from SIOS partner data repositories into a unified endpoint. The catalogue allows for discovery of metadata via numerous APIs (CSW 2/CSW 3, OpenSearch, OAI-PMH), and supports different output profiles.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=874a60f6-f982-4b24-9b39-c385cdea27f1',
#    'id': '874a60f6-f982-4b24-9b39-c385cdea27f1',
#    'status': 0,
#    'title': 'Machine readable metadata endpoint (OGC-CSW) for the Svalbard Integrated Arctic Earth Observing System (SIOS)',
#    'uid': 'SIOSCSWEndpoint'},
#   {'description': 'The IAGOS Data Portal provides observational data and added-value products produced by the European Research Infrastructure IAGOS. Datasets can be discovered and downloaded through the IAGOS REST API. Data and metadata follow the standards for Atmosphere community.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=15b4e4be-9e75-4e0c-9ca4-86c8ab08f0da',
#    'id': '15b4e4be-9e75-4e0c-9ca4-86c8ab08f0da',
#    'status': 0,
#    'title': 'IAGOS Data Portal - REST API for data and metadata access',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/a558d2ea-1b63-481b-b8cd-f9e05e13d8c2'},
#   {'description': 'The IAGOS Data Portal provides observational data and added-value products produced by the European Research Infrastructure IAGOS. Datasets can be discovered and downloaded through the portal. Data and metadata follow the standards for Atmosphere community.',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=93fd8e28-dc4a-46f5-8934-2b1298a6369f',
#    'id': '93fd8e28-dc4a-46f5-8934-2b1298a6369f',
#    'status': 0,
#    'title': 'IAGOS Data Portal - Human readable interface',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/5a3deb19-f10e-47b8-abab-91ac71a4ca0c'},
#   {'availableFormats': [{'format': 'text/turtle',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=2fcb9aea-bfaf-4600-9010-4c134b4da309&format=text/turtle',
#      'label': 'TEXT/TURTLE',
#      'originalFormat': 'text/turtle',
#      'type': 'ORIGINAL'}],
#    'description': "Marine Regions provides a standard, relational list of geographic names coupled with information and maps of the geographic locations of these features. The improves access to and clarity of geographic marine names such as seas, sandbanks, ridges, bays, boundaries, inlets, etc, and provides unambiguous information on the boundaries of marine biogeographic and managerial marine areas. Marine Regions gathers data on marine objects from various sources (authoritative databases, ecological classifications, etc) and where available, includes their geometries. In addition, conceptual information (e.g. the type of object) are added and  organised in a hierarchy. Each object is assigned a unique ID (MRGID: the marine region geographic ID), which allows for unambiguous reference to the objects, effectively forming a unique and permanent vocabulary of marine region object names. Marine Regions is part of the LifeWatch project, and serves as a geographical basis for biodiversity databases, global fisheries research, and maritime applications. Marine Regions activities focus on two main outputs: its gazetteer and its geographical data products. The gazetteer provides a standard list of marine geographical place names and locations; its data products highlight particular geographical objects, the most popular one being the Marine Regions Maritime Boundaries. Marine regions also provides a number of webservices. The LDES service: all gazetter entries are exposed as Linked Data Event Streams (LDES), with one Event Stream page per hour. Each page contains a link to the next/previous page, and each MRGID URI is versioned by adding a 't' query parameter, indicating the time of the change.",
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=2fcb9aea-bfaf-4600-9010-4c134b4da309',
#    'id': '2fcb9aea-bfaf-4600-9010-4c134b4da309',
#    'status': 0,
#    'title': 'Marine Regions gazetteer',
#    'uid': 'https://marineinfo.org/id/dataset/marineregionsgazetteer_REST'},
#   {'availableFormats': [{'format': 'application/json',
#      'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=96777704-8be4-456e-b79b-e216cd7acc25&format=application/json',
#      'label': 'APPLICATION/JSON',
#      'originalFormat': 'application/json',
#      'type': 'ORIGINAL'}],
#    'description': 'CDI SPARQL Endpoint',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=96777704-8be4-456e-b79b-e216cd7acc25',
#    'id': '96777704-8be4-456e-b79b-e216cd7acc25',
#    'status': 0,
#    'title': 'CDI SPARQL Endpoint',
#    'uid': 'https://www.epos-eu.org/epos-dcat-ap/Distribution/898d5028-b8c9-43f0-a19a-a330355034a4'}]}

# %% [markdown]
# Each one of the *results* object has these properties:
# - "**availableFormats**": an array of elements each representing a file format that can be downloaded for this resource, including the format type, the url to get the resource with that specific format, a label, and type which define if the format is natively available of it needs a conversion.
# - "ddss": a string representing the identifier of the resource.
# - "**description**": a string containing a detailed description of the dataset, including the purpose, content, and objectives.
# - "**href**": a string representing the URL where the EPOS ICS-C API serve the details of the resources.
# - "id": a string representing the unique identifier of this dataset.
# - "status": an integer representing the status of the resource.
# - "**title**": a string representing the title of the resource.
# - "**uid**": a string representing the unique identifier of the resource.

# %% [markdown]
# Here it is an instance of the first resource:

# %%
data['results'][0]
# Out:
# {'availableFormats': [{'format': 'application/json',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=7d5bc4cc-d353-4542-8890-3d8abc833033&format=application/json',
#    'label': 'APPLICATION/JSON',
#    'originalFormat': 'application/json',
#    'type': 'ORIGINAL'}],
#  'description': 'Map of the flattened phase difference (full evolution) computed between two SAR images acquired over the same scene with the same geometry',
#  'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=7d5bc4cc-d353-4542-8890-3d8abc833033',
#  'id': '7d5bc4cc-d353-4542-8890-3d8abc833033',
#  'status': 1,
#  'title': 'Unwrapped Interferograms',
#  'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Unwrapped_Interferogram/Distribution/Unwrap_Interf'}

# %% [markdown]
# ## Details
#
# The details function of the EPOS ICS-C API allows users to retrieve detailed information about a specific seismic event. Users can query the API using the unique ID assigned to each resource in the database.
#
# To retrieve all the detailed information about this resource is enough to do a GET request, using also this time the *requests* library, on the *href* property.

# %%
response_detail = requests.get(data['results'][0]['href'])
data_details = response_detail.json()

# %% [markdown]
# The details response payload have this structure:
# - **availableFormats**: an array that contains multiple object with details about the available format for the data, one for each available format.
# - **dataProvider**: an array that contains objects with details about the data provider of the resource, one resource can have multiple dataprovider and each one of these can have multiple dataproviders related, also, if available is present an url to the page of the dataprovider.
# - **description**: a string that describes the purpose and objectives of the resource.
# - **downloadURL**: This property contains a URL that is a direct link to a downloadable file in a given format. An empty string indicating that there is no download URL available.
# - **endpoint**: a string that provides the URL endpoint for accessing the data.
# - **frequencyUpdate**: a string that indicates the frequency or the strategy of updates to the data.
# - **hasQualityAnnotation**: a string that provides a link to information about the quality assurance of the data.
# - **href**: a string that provides a link to the details of the resource.
# - **id**: a string that serves as a unique identifier for the resource.
# - **internalID**: an array that contains the internal identifier for the resource.
# - **keywords**: an array of strings that contain keywords related to the data.
# - **license**: a string that provides a link to the license agreement for accessing the data.
# - **operationid**: a string that provides a link to the operation of the resource, it contains the unique identifier of the operation.
# - **scienceDomain**: an array that provides the science domain of the resource.
# - **serviceDescription**: a string that describes the purpose of the web service.
# - **serviceDocumentation**: a string that provides a link to the documentation for the web service.
# - **serviceEndpoint**: a string that provides the URL endpoint for accessing the web service.
# - **serviceName**: a string that provides the name of the web service.
# - **serviceParameters**: an array that contains an object with details about the parameters required to use the web service (in this case, the parameter "start" is required and has a default value of "19821001").
# - **serviceProvider**: an object with details about the service provider of the resource, one resource can have one service provider and each one of these can have multiple service providers related, also, if available is present an url to the page of the serviceprovider.
# - **serviceSpatial**: an object that contains spatial information about the service like a path of coordinates.
# - **serviceTemporalCoverage**: an object that provides temporal coverage information for the service.
# - **serviceType**: an array that provides the type of the service.
# - **spatial**: an object that contains spatial information about the resource like a path defined by a set of coordinates.
# - **temporalCoverage**: an object that provides temporal coverage information for the resource.
# - **title**: a string that provides the title of the resource.
# - **type**: a string that provides the type of the resource.
# - **uid**: a string that serves as a unique identifier of the resource.

# %%
data_details
# Out:
# {'availableFormats': [{'format': 'application/json',
#    'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/execute?id=7d5bc4cc-d353-4542-8890-3d8abc833033&format=application/json',
#    'label': 'APPLICATION/JSON',
#    'originalFormat': 'application/json',
#    'type': 'ORIGINAL'}],
#  'dataProvider': [{'dataProviderLegalName': 'EPOS',
#    'dataProviderUrl': 'https://www.epos-eu.org/'}],
#  'description': 'Map of the flattened phase difference (full evolution) computed between two SAR images acquired over the same scene with the same geometry',
#  'downloadURL': '',
#  'endpoint': 'https://catalog.terradue.com/gep-epos/search?format=json&pt=UNWRAPPED_INTERFEROGRAM{&start, stop, geom, track, uid, od, psn, count, q}&bbox={minLongitude, minLatitude, maxLongitude, maxLatitude}',
#  'frequencyUpdate': 'http://purl.org/cld/freq/continuous',
#  'href': 'https://ics-c.epos-ip.org/demo/k8s-epos-deploy/envri-fair-catalogue/api/v1/resources/details?id=7d5bc4cc-d353-4542-8890-3d8abc833033',
#  'id': '7d5bc4cc-d353-4542-8890-3d8abc833033',
#  'keywords': ['https://gcmd.earthdata.nasa.gov/kms/concept/a37282d4-322c-4dd0-8edc-36099b9b586c',
#   'http://publications.europa.eu/resource/authority/8mn/euroscivoc/acfa84a9-7d59-42ba-8028-92bdad6272d1'],
#  'license': 'https://creativecommons.org/licenses/by/4.0/',
#  'operationid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/WebService/UNWRAPPED_INTERFEROGRAM/Operation/Search',
#  'scienceDomain': ['https://gcmd.earthdata.nasa.gov/kms/concept/2b9ad978-d986-4d63-b477-0f5efc8ace72'],
#  'serviceDescription': 'Map of the flattened phase difference (full evolution) computed between two SAR images acquired over the same scene with the same geometry. The Differential Interferogram is linerly related to the Line of Sight projection of the actual surface deformation.',
#  'serviceDocumentation': 'https://docs.terradue.com/ellip/core/da/catalog/search.html#',
#  'serviceEndpoint': 'https://catalog.terradue.com/gep-epos/search?format=json&pt=UNWRAPPED_INTERFEROGRAM',
#  'serviceName': 'Unwrapped Differential Interferogram (Phase and Amplitude)',
#  'serviceParameters': [{'label': 'Relative Orbit Number (Track)',
#    'name': 'track',
#    'required': False,
#    'type': 'integer'},
#   {'defaultValue': '2039-01-01T00:00:00',
#    'label': 'To',
#    'name': 'stop',
#    'property': 'schema:endDate',
#    'required': False,
#    'type': 'dateTime',
#    'valuePattern': 'YYYY-MM-DDThh:mm:ss'},
#   {'defaultValue': '2014-01-01T00:00:00',
#    'label': 'From',
#    'name': 'start',
#    'property': 'schema:startDate',
#    'required': False,
#    'type': 'dateTime',
#    'valuePattern': 'YYYY-MM-DDThh:mm:ss'},
#   {'defaultValue': '72.0',
#    'label': 'Maximum Latitude',
#    'maxValue': '90.0',
#    'minValue': '-90.0',
#    'name': 'maxLatitude',
#    'property': 'epos:northernmostLatitude',
#    'required': True,
#    'type': 'float'},
#   {'Enum': ['S1'],
#    'defaultValue': 'S1',
#    'label': 'Satellite Platform',
#    'name': 'psn',
#    'required': False,
#    'type': 'string'},
#   {'label': 'Search Area in WKT format for custom polygons: POLYGON((Lon1 Lat1, Lon2 Lat2, ..., Lon1 Lat1))',
#    'name': 'geom',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '60.0',
#    'label': 'Maximum Longitude',
#    'maxValue': '180.0',
#    'minValue': '-180.0',
#    'name': 'maxLongitude',
#    'property': 'epos:easternmostLongitude',
#    'required': True,
#    'type': 'float'},
#   {'label': 'Product Name (insert the Product Name to find a specific product)',
#    'name': 'uid',
#    'required': False,
#    'type': 'string'},
#   {'Enum': ['ASCENDING', 'DESCENDING'],
#    'label': 'Orbit Direction',
#    'name': 'od',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '20',
#    'label': 'Number of returned results',
#    'maxValue': '500',
#    'minValue': '1',
#    'name': 'count',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '-25.0',
#    'label': 'Minimum Longitude',
#    'maxValue': '180.0',
#    'minValue': '-180.0',
#    'name': 'minLongitude',
#    'property': 'epos:westernmostLongitude',
#    'required': True,
#    'type': 'float'},
#   {'Enum': ['COMET', 'CNRIREA', 'GDMCNRS'],
#    'label': 'Data Provider',
#    'name': 'q',
#    'required': False,
#    'type': 'string'},
#   {'defaultValue': '15.0',
#    'label': 'Minimum Latitude',
#    'maxValue': '90.0',
#    'minValue': '-90.0',
#    'name': 'minLatitude',
#    'property': 'epos:southernmostLatitude',
#    'required': True,
#    'type': 'float'}],
#  'serviceProvider': {'dataProviderLegalName': 'EPOS',
#   'dataProviderUrl': 'https://www.epos-eu.org/'},
#  'serviceSpatial': {'paths': [[[-180.0, -90.0],
#     [-180.0, 90.0],
#     [180.0, 90.0],
#     [180.0, -90.0],
#     [-180.0, -90.0]]],
#   'wkid': 4326},
#  'serviceTemporalCoverage': {'startDate': '1978-01-01T00:00:00Z'},
#  'serviceType': ['stypes:SpatialService', 'stypes:DataService'],
#  'spatial': {'paths': [[[-180.0, -90.0],
#     [180.0, -90.0],
#     [180.0, 90.0],
#     [-180.0, 90.0],
#     [-180.0, -90.0]]],
#   'wkid': 4326},
#  'temporalCoverage': {'startDate': '1978-01-01T00:00:00Z'},
#  'title': 'Unwrapped Interferograms',
#  'type': 'WEB_SERVICE',
#  'uid': 'https://catalog.terradue.com/gep-epos/SatelliteObservations/Dataset/Unwrapped_Interferogram/Distribution/Unwrap_Interf'}

# %% [markdown]
# ## Download original data
#
# To download the original data of one of the resource is enough to use the *requests* to execute a GET request using the id of  the resource and on the original URL endpoint

# %%
import urllib.parse
response_original_url = requests.get(api_url + '/getoriginalurl?id=' + urllib.parse.quote(data_details['id'].encode('utf8')))
data_original_url = response_original_url.json()

# %% [markdown]
# The response is a Json Object with only one property: *url*.
# The url is where the resource is located.

# %%
data_original_url
# Out:
# {'detail': 'The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.',
#  'status': 404,
#  'title': 'Not Found',
#  'type': 'about:blank'}

# %% [markdown]
# Using *requests* is possible to get the information located at that URL

# %%
response_original_data = requests.get(data_original_url['url'])
original_data = response_original_data.content
original_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 response_original_data = requests.get(data_original_url['url'])
#       2 original_data = response_original_data.content
#       3 original_data
#
# KeyError: 'url'

# %% [markdown]
# ## Use case
#
# A user want to do some analysis on some sismic data distributed by the KMNI.

# %% [markdown]
# ### Search of the data
#
# The user do the search request asking to filter on this string: "Seismic waveforms distributed by the ORFEUS Data Center at KNMI" (The string needs to be url encoded)

# %%
response_search_filtered = requests.get(api_url + "/search?facets=false&q=" + urllib.parse.quote('Seismic waveforms distributed by the ORFEUS Data Center at KNMI'.encode('utf8')))
filtered_data = response_search_filtered.json()
filtered_data

# %% [markdown]
# It returned only one result

# %% [markdown]
# ### Get the data
#
# The user get the data of the resource from the source. Before he get from the ICS-C API the url of the original resource, then he queries the service to get the actual data.

# %%
response_INGV_original_url= requests.get(api_url + '/getoriginalurl?id=' + filtered_data['results'][0]['id'])
original_url_INGV = response_INGV_original_url.json()['url']

response_INGV_data = requests.get(original_url_INGV)
INGV_data = response_INGV_data.content

# %% [markdown]
# #### Save the data on file
#
# The user know from the search that the data which he had just retrieved is a *miniseed* file, because in the *availableFormats* it shows that the original file format. So he save it on a file.

# %%
with open("INGV_data.mseed", "wb") as f:
    f.write(INGV_data)

# %% [markdown]
# ### Visualize the data
#
# Then he decide to visualize the waves using obspy library.

# %%
from obspy import read

st = read("INGV_data.mseed", format='mseed')
st.plot()

# %%
st.spectrogram()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 st.spectrogram()
#
# File /usr/local/lib/python3.9/site-packages/obspy/core/stream.py:1178, in Stream.spectrogram(self, **kwargs)
#    1176 spec_list = []
#    1177 for tr in self:
# -> 1178     spec = tr.spectrogram(**kwargs)
#    1179     spec_list.append(spec)
#    1181 return spec_list
#
# File /usr/local/lib/python3.9/site-packages/obspy/core/trace.py:971, in Trace.spectrogram(self, **kwargs)
#     969     kwargs['title'] = str(self)
#     970 from obspy.imaging.spectrogram import spectrogram
# --> 971 return spectrogram(data=self.data, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/obspy/imaging/spectrogram.py:215, in spectrogram(data, samp_rate, per_lap, wlen, log, outfile, fmt, axes, dbscale, mult, cmap, zorder, title, show, clip)
#     213         fig.savefig(outfile)
#     214 elif show:
# --> 215     plt.show()
#     216 else:
#     217     return fig
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py:445, in show(*args, **kwargs)
#     401 """
#     402 Display all open figures.
#     403
#    (...)
#     442 explicitly there.
#     443 """
#     444 _warn_if_gui_out_of_main_thread()
# --> 445 return _get_backend_mod().show(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File /usr/local/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2332     renderer = _get_renderer(
#    2333         self.figure,
#    2334         functools.partial(
#    2335             print_method, orientation=orientation)
#    2336     )
#    2337     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2338         self.figure.draw(renderer)
#    2340 if bbox_inches:
#    2341     if bbox_inches == "tight":
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/figure.py:3125, in Figure.draw(self, renderer)
#    3122         # ValueError can occur when resizing a window.
#    3124 self.patch.draw(renderer)
# -> 3125 mimage._draw_list_compositing_images(
#    3126     renderer, self, artists, self.suppressComposite)
#    3128 for sfig in self.subfigs:
#    3129     sfig.draw(renderer)
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py:3066, in _AxesBase.draw(self, renderer)
#    3063 if artists_rasterized:
#    3064     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3066 mimage._draw_list_compositing_images(
#    3067     renderer, self, artists, self.figure.suppressComposite)
#    3069 renderer.close_group('axes')
#    3070 self.stale = False
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/image.py:641, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     639         renderer.draw_image(gc, l, b, im, trans)
#     640 else:
# --> 641     im, l, b, trans = self.make_image(
#     642         renderer, renderer.get_image_magnification())
#     643     if im is not None:
#     644         renderer.draw_image(gc, l, b, im)
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/image.py:949, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     946 transformed_bbox = TransformedBbox(bbox, trans)
#     947 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     948         else self.figure.bbox)
# --> 949 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     950                         magnification, unsampled=unsampled)
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/image.py:518, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     513 mask = (np.where(A.mask, np.float32(np.nan), np.float32(1))
#     514         if A.mask.shape == A.shape  # nontrivial mask
#     515         else np.ones_like(A, np.float32))
#     516 # we always have to interpolate the mask to account for
#     517 # non-affine transformations
# --> 518 out_alpha = _resample(self, mask, out_shape, t, resample=True)
#     519 del mask  # Make sure we don't use mask anymore!
#     520 # Agg updates out_alpha in place.  If the pixel has no image
#     521 # data it will not be updated (and still be 0 as we initialized
#     522 # it), if input data that would go into that output pixel than
#     523 # it will be `nan`, if all the input data for a pixel is good
#     524 # it will be 1, and if there is _some_ good data in that output
#     525 # pixel it will be between [0, 1] (such as a rotated image).
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/image.py:207, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     205 if resample is None:
#     206     resample = image_obj.get_resample()
# --> 207 _image.resample(data, out, transform,
#     208                 _interpd_[interpolation],
#     209                 resample,
#     210                 alpha,
#     211                 image_obj.get_filternorm(),
#     212                 image_obj.get_filterrad())
#     213 return out
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/transforms.py:2405, in CompositeGenericTransform.<lambda>(self)
#    2402         yield self._a + left, right
#    2404 depth = property(lambda self: self._a.depth + self._b.depth)
# -> 2405 is_affine = property(lambda self: self._a.is_affine and self._b.is_affine)
#    2406 is_separable = property(
#    2407     lambda self: self._a.is_separable and self._b.is_separable)
#    2408 has_inverse = property(
#    2409     lambda self: self._a.has_inverse and self._b.has_inverse)
#
# KeyboardInterrupt:

# %%
tr=st[0]


#stPlot.append(st[0].copy())

#print(stPlot)
# stPlot.plot(size=(800, 600))
tr.spectrogram(log=True, title='BW.RJOB ' + str(st[0].stats.starttime))

# %%
tr = st[0]

#stPlot.append(st[0].copy())

#print(stPlot)
# stPlot.plot(size=(800, 600))
tr.spectrogram(log=True, title='BW.RJOB ' + str(st[0].stats.starttime))

# %%
st.detrend('linear')
tr = st[0]
tr.spectrogram(log=True, title='envriCat')
